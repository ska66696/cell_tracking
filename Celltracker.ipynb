# %% [markdown]
# # Cell Tracking Program
# <br><MTMarkdownOptions output='html4'>
#     The propose of this project is to develop an algorithm to realize HeLa cell cycle analysis by cell segmentation and cell tracking. Our segmentation algorithm includes binarization, nuclei center detection and nuclei boundary delineating; and our tracking algorithm includes neighboring graph construction, optimal matching, cell division, death, segmentation errors detection and processing, and refined segmentation and matching results. Our chosen testing and training datasets are Histone 2B (H2B)-GFP expressing HeLa cells provided by Mitocheck Consortium. This project used Jaccard index to measure the segmentation accuracy and TRA method for tracking. Our results, respectably 69.51% and 74.61%, demonstrated the validity of the developed algorithm in investigation of cancer cell cycle, the problems and further improvements of our algorithm are also mentioned.
# </MTMarkdownOptions><br><br>

# %% [markdown]
# ## 0. Prepare Import File and Import Image Set

# %%
# %matplotlib inline

import os
import cv2
import PIL.Image
import sys
import numpy as np
from IPython.display import Image, display, clear_output
import matplotlib.pyplot as plt
import scipy

def normalize(image):
    '''
    This function is to normalize the input grayscale image by
    substracting globle mean and dividing standard diviation for
    visualization. 

    Input:  a grayscale image

    Output: normolized grascale image

    '''
    cv2.normalize(image, image, 0, 255, cv2.NORM_MINMAX)
    return image

# read image sequence
path=os.path.join("resource/training/01")
# The dataset could be download through: http://www.codesolorzano.com/Challenges/CTC/Datasets.html
for r,d,f in os.walk(path):
    images = []
    enhance_images = []
    f = sorted(f)
    for files in f:
        if files[-3:].lower()=='tif':
            temp = cv2.imread(os.path.join(r,files))
            gray = cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY) 
            images.append(gray.copy())
            enhance_images.append(normalize(gray.copy()))
            


print ("Total number of image is ", len(images))
print ("The shape of image is ", images[0].shape, type(images[0][0,0]))
# Out:
# Total number of image is  92
# The shape of image is  (700, 1100) <class 'numpy.uint8'>

# %%
# Helper functions
def display_image(img):
    assert img.ndim == 2 or img.ndim == 3
    h, w = img.shape[:2]
    if len(img.shape) == 3:
        img = cv2.resize(img, (w/3, h/3, 3))
    else:
        img = cv2.resize(img, (w/3, h/3))
    cv2.imwrite("temp_img.png", img)
    img = Image("temp_img.png")
    display(img)

def vis_square(data, title=None):
    """
    Take an array of shape (n, height, width) or (n, height, width, 3)
    and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)
    """
    # resize image into small size
    _, h, w = data.shape[:3] 
    width = int(np.ceil(1200. / np.sqrt(data.shape[0])))    # the width of showing image 
    height = int(np.ceil(h*float(width)/float(w))) # the height of showing image 
    if len(data.shape) == 4:
        temp = np.zeros((data.shape[0], height, width, 3))
    else:
        temp = np.zeros((data.shape[0], height, width))
    
    for i in range(data.shape[0]):
        if len(data.shape) == 4:
            temp[i] = cv2.resize(data[i], (width, height, 3))
        else:
            temp[i] = cv2.resize(data[i], (width, height))
    
    data = temp
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = (((0, n ** 2 - data.shape[0]),
              (0, 2), (0, 2))                 # add some space between filters
              + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    data = np.pad(data, padding, mode='constant', constant_values=255)  # pad with ones (white)
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    # show image
    cv2.imwrite("temp_img.png", data)
    img = Image("temp_img.png")
    display(img)

def cvt_npimg(images):
    """
    Convert image sequence to numpy array
    """
    h, w = images[0].shape[:2]
    if len(images[0].shape) == 3:
        out = np.zeros((len(images), h, w, 3))
    else:
        out = np.zeros((len(images), h, w))
    for i, img in enumerate(images):
        out[i] = img
    return out

# %%
# Write image from different input
def write_mask16(images, name, index=-1):
    """
    Write image as 16 bits image
    """
    if index == -1:
        for i, img in enumerate(images):
            if i < 10:
                cv2.imwrite(name+"00"+str(i)+".tif", img.astype(np.uint16))
            elif i >= 10 and i < 100:
                cv2.imwrite(name+"0"+str(i)+".tif", img.astype(np.uint16))
            else:
                cv2.imwrite(name+str(i)+".tif", img.astype(np.uint16))
    else:
        if index < 10:
            cv2.imwrite(name+"00"+str(index)+".tif", images.astype(np.uint16))
        elif index >= 10 and index < 100:
            cv2.imwrite(name+"0"+str(index)+".tif", images.astype(np.uint16))
        else:
            cv2.imwrite(name+str(index)+".tif", images.astype(np.uint16))   

def write_mask8(images, name, index=-1):
    """
    Write image as 8 bits image
    """
    if index == -1:
        for i, img in enumerate(images):
            if i < 10:
                cv2.imwrite(name+"00"+str(i)+".tif", img.astype(np.uint8))
            elif i >= 10 and i < 100:
                cv2.imwrite(name+"0"+str(i)+".tif", img.astype(np.uint8))
            else:
                cv2.imwrite(name+str(i)+".tif", img.astype(np.uint8))
    else:
        if index < 10:
            cv2.imwrite(name+"000"+str(index)+".tif", images.astype(np.uint8))
        elif index >= 10 and index < 100:
            cv2.imwrite(name+"00"+str(index)+".tif", images.astype(np.uint8))
        elif index >= 100 and index < 1000:
            cv2.imwrite(name+"0"+str(index)+".tif", images.astype(np.uint8)) 
        else:
            cv2.imwrite(name+str(index)+".tif", images.astype(np.uint8)) 

def write_pair8(images, name, index=-1):
    """
    Write image as 8 bits image with dilation
    """
    for i, img in enumerate(images):    
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
        img = cv2.dilate((img*255).astype(np.uint8),kernel,iterations = 3)
        if i < 10:
            cv2.imwrite(name+"00"+str(i)+".tif", img)
        elif i >= 10 and i < 100:
            cv2.imwrite(name+"0"+str(i)+".tif", img)
        else:
            cv2.imwrite(name+str(i)+".tif", img)

# %% [markdown]
# ## 1. Cell Segmentatioin Part
# <br>
# <MTMarkdownOptions output='html4'>
#     1. Adaptive Thresholding
#     <br>
#     This file is to compute adaptive thresholding of image sequence in
#     order to generate binary image for Nuclei segmentation.
#
#     Problem:
#     Due to the low contrast of original image, the adaptive thresholding is not working.
#     Therefore, we change to regular threshold with threshold value as 129.
# </MTMarkdownOptions>

# %%
th = None
img = None

class ADPTIVETHRESH():
    '''
    This class is to provide all function for adaptive thresholding.

    '''
    def __init__(self, images):
        self.images = []
        for img in images:
            if len(img.shape) == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            self.images.append(img.copy())

    def applythresh(self, threshold = 50):
        '''
        applythresh function is to convert original image to binary image by thresholding.

        Input: image sequence. E.g. [image0, image1, ...]

        Output: image sequence after thresholding. E.g. [image0, image1, ...]
        '''
        out = []
        markers = []
        binarymark = []

        for img in self.images:
            img = cv2.GaussianBlur(img,(5,5),0).astype(np.uint8)
            _, thresh = cv2.threshold(img,threshold,1,cv2.THRESH_BINARY)

            # Using morphlogical operations to imporve the quality of result
            kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(9,9))
            thresh = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

            out.append(thresh)

        return out

# %%
# This part is for testing adaptivethresh.py with single image.
# Input: an original image
# Output: Thresholding image

global th
global img

adaptive = ADPTIVETHRESH(enhance_images)
th = adaptive.applythresh(50)

# %%
# display images
for i,img in enumerate(th):
    th[i] = img*255
os.chdir(".")
write_mask8(th, "thresh")
out = cvt_npimg(th)
vis_square(out)

# %% [markdown]
# <br>
# <MTMarkdownOptions output='html4'>
#     2. Gradient Filed Vector*
#     <br>
#     This file is to compute gradient vector field (GVF) and then find the Nuclei center
#     with the GVF result. (This part is optinal and I recommend using the distance map directly)
# </MTMarkdownOptions>

# %%
from scipy import spatial as sp
from scipy import ndimage
from scipy.spatial import distance

looplimit = 500

newimg = None
pair = None

def inbounds(shape, indices):
    assert len(shape) == len(indices)
    for i, ind in enumerate(indices):
        if ind < 0 or ind >= shape[i]:
            return False
    return True

class GVF():
    '''
    This class contains all function for calculating GVF and its following steps.
    
    '''
    def __init__(self, images, thresh):
        
        self.images = images
        self.thresh = thresh

    def distancemap(self):
        '''
        This function is to generate distance map of the thresh image. We use the opencv
        function distanceTransform to generate it. Moreover, in this case, we use Euclidiean
        Distance (DIST_L2) as a metric of distance. 

        Input: None

        Output: Image distance map

        '''
        return [cv2.distanceTransform(self.thresh[i], distanceType=2, maskSize=0)\
                for i in range(len(self.thresh))]

    def new_image(self, alpha, dismap):
        '''
        This function is to generate a new image combining the oringal image I0 with
        the distance map image Idis by following expression:
                                Inew = I0 + alpha*Idis
        In this program, we choose alpha as 0.4.

        Input: the weight of distance map: alpha
               the distance map image

        Output: new grayscale image

        '''

        return [self.images[i] + alpha * dismap[i] for i in range(len(self.thresh))]

    def compute_gvf(self, newimage):
        '''
        This function is to compute the gradient vector of the imput image.

        Input: a grayscale image with size, say m * n * # of images

        Output: a 3 dimentional image with size, m * n * 2, where the last dimention is
        the gradient vector (gx, gy)

        '''
        kernel_size = 5 # kernel size for blur image before compute gradient
        newimage = [cv2.GaussianBlur((np.clip(newimage[i], 0, 255)).astype(np.uint8),(kernel_size,kernel_size),0)\
                    for i in range(len(self.thresh))]
        # use sobel operator to compute gradient 
        temp = np.zeros((newimage[0].shape[0], newimage[0].shape[1], 2), np.float32) # store temp gradient image 
        gradimg = []  # output gradient images (height * weight * # of images)

        for i in range(len(newimage)):
            # compute sobel operation in x, y directions
            gradx = cv2.Sobel(newimage[i],cv2.CV_64F,1,0,ksize=3)
            grady = cv2.Sobel(newimage[i],cv2.CV_64F,0,1,ksize=3)
            # add the gradient vector
            temp[:,:,0], temp[:,:,1] = gradx, grady
            gradimg.append(temp)

        return gradimg

    def find_certer(self, gvfimage, index):
        '''
        This function is to find the center of Nuclei.

        Input: the gradient vector image (height * weight * 2).

        Output: the record image height * weight).

        '''
        # Initialize a image to record seed candidates.
        imgpair = np.zeros(gvfimage.shape[:2])

        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
        dilate = cv2.dilate(self.thresh[index].copy(), kernel, iterations = 1)
        erthresh = cv2.erode(dilate, kernel, iterations = 3)
        while erthresh.sum() > 0:

            print ("Image ", index, "left: ", erthresh.sum(), "points")
            # Initialize partical coordinates [y, x]
            y0, x0 = np.where(erthresh>0)
            p0 = np.array([y0[0], x0[0], 1])

            # Initialize record coordicates [y, x]
            p1 = np.array([5000, 5000, 1])

            # mark the first non-zero point of thresh image to 0
            erthresh[p0[0], p0[1]] = 0

            # a variable to record if the point out of bound of image or 
            # out of maximum loop times
            outbound = False

            # count loop times to limit max loop times
            count = 0

            while sp.distance.cdist([p0],[p1]) > 1:

                count += 1
                p1 = p0
                u = gvfimage[int(p0[0]), int(p0[1]), 1]
                v = gvfimage[int(p0[0]), int(p0[1]), 0]
                M = np.array([[1, 0, u],\
                              [0, 1, v],\
                              [0, 0, 1]], np.float32)
                p0 = M.dot(p0)
                if not inbounds(self.thresh[index].shape, (p0[0], p0[1])) or count > looplimit:
                    outbound = True
                    break

            if not outbound:
                imgpair[int(p0[0]), int(p0[1])] += 1
            clear_output(wait=True)

        return imgpair.copy()

# %%
# This part is for testing gvf.py with single image. (Optional)
# Input: an original image
# Output: Thresholding image and seed image

global th
global newimg
global pair
# Nuclei center detection
gvf = GVF(images, th)
dismap = gvf.distancemap()
newimg = gvf.new_image(0.4, dismap) # choose alpha as 0.4.
gradimg = gvf.compute_gvf(newimg)
out = []
pair = []
pair_raw = []
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
i = 0
for i,img in enumerate(gradimg):
    print(i)
    imgpair_raw = gvf.find_certer(img, i)
    pair_raw.append(imgpair_raw)
    neighborhood_size = 20
    data_max = ndimage.filters.maximum_filter(pair_raw[i], neighborhood_size)
    data_max[data_max==0] = 255
    pair.append((pair_raw[i] == data_max).astype(np.uint8))
    write_mask8(np.array([pair[i]]), "pair_raw", i)
    os.chdir("D:/Downloads/tsa_team_project/temporary_result")
    y, x = np.where(pair[i]>0)
    points = list(zip(y[:], x[:]))
    dmap = distance.cdist(points, points, 'euclidean')
    y, x = np.where(dmap<10)
    ps = zip(y[:], x[:])
    for p in ps:
        if p[0] != p[1]:
            pair[i][points[min(p[0], p[1])]] = 0
    dilation = cv2.dilate((pair[i]*255).astype(np.uint8),kernel,iterations = 3)
    out.append(dilation)

out = cvt_npimg(out)
vis_square(out)
# Out:
# Image  0 left:  6128415 points
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2080\3312987457.py in <module>
#      18 for i,img in enumerate(gradimg):
#      19     print(i)
# ---> 20     imgpair_raw = gvf.find_certer(img, i)
#      21     pair_raw.append(imgpair_raw)
#      22     neighborhood_size = 20
#
# ~\AppData\Local\Temp\ipykernel_2080\3846707286.py in find_certer(self, gvfimage, index)
#     133             if not outbound:
#     134                 imgpair[int(p0[0]), int(p0[1])] += 1
# --> 135             clear_output(wait=True)
#     136
#     137         return imgpair.copy()
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in clear_output(wait)
#    1469     from IPython.core.interactiveshell import InteractiveShell
#    1470     if InteractiveShell.initialized():
# -> 1471         InteractiveShell.instance().display_pub.clear_output(wait)
#    1472     else:
#    1473         print('\033[2K\r', end='')
#
# ~\anaconda3\lib\site-packages\ipykernel\zmqshell.py in clear_output(self, wait)
#     144         """
#     145         content = dict(wait=wait)
# --> 146         self._flush_streams()
#     147         self.session.send(
#     148             self.pub_socket,
#
# ~\anaconda3\lib\site-packages\ipykernel\zmqshell.py in _flush_streams(self)
#      63     def _flush_streams(self):
#      64         """flush IO Streams prior to display"""
# ---> 65         sys.stdout.flush()
#      66         sys.stderr.flush()
#      67
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in flush(self)
#     478             self.pub_thread.schedule(evt.set)
#     479             # and give a timeout to avoid
# --> 480             if not evt.wait(self.flush_timeout):
#     481                 # write directly to __stderr__ instead of warning because
#     482                 # if this is happening sys.stderr may be the problem.
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     579             signaled = self._flag
#     580             if not signaled:
# --> 581                 signaled = self._cond.wait(timeout)
#     582             return signaled
#     583
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# <br>
# <MTMarkdownOptions output='html4'>
#     GVF enhance*
#     <br>
#     This file is to amend the seed points for watershed. (This part is optinal and I recommend using the distance map directly)
# </MTMarkdownOptions>

# %%
from scipy import spatial as sp
from scipy import ndimage
from scipy.spatial import distance

gvf = GVF(images, th)
dismap = gvf.distancemap()
newimg = gvf.new_image(0.4, dismap) # choose alpha as 0.4.
# TODO this part is designed to amend the result of gvf. 
pair = []
path=os.path.join("D:/Downloads/tsa_team_project/temporary_result")
for r,d,f in os.walk(path):
    for files in f:
        if files[:5].lower()=='seed':
            print (files)
            temp = cv2.imread(os.path.join(r,files))
            temp = cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY) 
            y, x = np.where(temp>0)
            points = zip(y[:], x[:])
            dmap = distance.cdist(points, points, 'euclidean')
            y, x = np.where(dmap<10)
            ps = zip(y[:], x[:])
            for p in ps:
                if p[0] != p[1]:
                    temp[points[min(p[0], p[1])]] = 0
            pair.append(temp)
            clear_output(wait=True)
print ("finish!")
# Out:
# finish!

# %% [markdown]
# <br>
# <MTMarkdownOptions output='html4'>
#     2. Distance Map (Recommend)
#     <br>
#     This file uses distance map to generate the seed points for watershed. Although it has nothing to do with GVF, you still need to load the GVF class, since it needs some helper functions in the class.
# </MTMarkdownOptions>

# %%
gvf = GVF(images, th)
dismap = gvf.distancemap()
newimg = gvf.new_image(0.4, dismap) # choose alpha as 0.4.
out = []
pair = []
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
for i,img in enumerate(dismap):
    neighborhood_size = 20
    data_max = ndimage.filters.maximum_filter(img, neighborhood_size)
    data_max[data_max==0] = 255
    pair.append((img == data_max).astype(np.uint8))
    y, x = np.where(pair[i]>0)
    points = list(zip(y[:], x[:]))
    dmap = distance.cdist(points, points, 'euclidean')
    y, x = np.where(dmap<20)
    ps = zip(y[:], x[:])
    for p in ps:
        if p[0] != p[1]:
            pair[i][points[min(p[0], p[1])]] = 0
    dilation = cv2.dilate((pair[i]*255).astype(np.uint8),kernel,iterations = 1)
    out.append(dilation)
    os.chdir(".")
    write_mask8(dilation, "seed_point", i)

out = cvt_npimg(out)
vis_square(out)
# Out:
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_2080\4142005630.py:9: DeprecationWarning: Please use `maximum_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   data_max = ndimage.filters.maximum_filter(img, neighborhood_size)

# %% [markdown]
# <br>
# <MTMarkdownOptions output='html4'>
#     3. Watershed
#     <br>
#     This file is to compute watershed given the seed image in the gvf.py.
# </MTMarkdownOptions>

# %%
import cv2
import numpy as np
from numpy import unique
import copy as cp

bmarks = None
marks = None

class WATERSHED():
    '''
    This class contains all the function to compute watershed.

    '''
    def __init__(self, images, markers):
        self.images = images
        self.markers = markers

    def is_over_long(self, img, max_lenth=50):
        rows = np.any(img, axis=1)
        cols = np.any(img, axis=0)
        if not len(img[img>0]):
            return True
        rmin, rmax = np.where(rows)[0][[0, -1]]
        cmin, cmax = np.where(cols)[0][[0, -1]]
        if (rmax-rmin)>max_lenth or (cmax-cmin)>max_lenth:
            return True
        else:
            return False
    
    def watershed_compute(self):
        '''
        This function is to compute watershed given the newimage and the seed image
        (center candidates). In this function, we use cv2.watershed to implement watershed.

        Input: newimage (height * weight * # of images)

        Output: watershed images (height * weight * # of images)

        '''
        result = []
        outmark = []
        outbinary = []

        for i in range(len(self.images)):
            print ("image: ", i)
            # generate a 3-channel image in order to use cv2.watershed
            imgcolor = np.zeros((self.images[i].shape[0], self.images[i].shape[1], 3), np.uint8)
            for c in range(3): 
                imgcolor[:,:,c] = self.images[i]

            # compute marker image (labelling)
            if len(self.markers[i].shape) == 3:
                self.markers[i] = cv2.cvtColor(self.markers[i],cv2.COLOR_BGR2GRAY)
            _, mark = cv2.connectedComponents(self.markers[i])
            
            # watershed!
            mark = cv2.watershed(imgcolor,mark)
            
            u, counts = unique(mark, return_counts=True)
            counter = dict(zip(u, counts))
            for index in counter:
                temp_img = np.zeros_like(mark)
                temp_img[mark==index] = 255
                if self.is_over_long(temp_img):
                    mark[mark==index] = 0
                    continue
                if counter[index] > 3000:
                    mark[mark==index] = 0
                    continue
            
            labels = list(set(mark[mark>0]))
            length = len(labels)
            temp_img = mark.copy()
            for original, new in zip(labels, range(1,length+1)):
                temp_img[mark==original] = new
            mark = temp_img
                
            # mark image and add to the result 
            temp = cv2.cvtColor(imgcolor,cv2.COLOR_BGR2GRAY)
            result.append(temp)
            outmark.append(mark.astype(np.uint8))

            binary = mark.copy()
            binary[mark>0] = 255
            outbinary.append(binary.astype(np.uint8))
            clear_output(wait=True)

        return result, outbinary, outmark

# %%
# This part is for testing watershed.py with single image.
# Output: Binary image after watershed

global bmarks
global marks

# watershed
ws = WATERSHED(newimg, pair) 
wsimage, bmarks, marks = ws.watershed_compute()

out = cvt_npimg(np.clip(bmarks, 0, 255)).astype(np.uint8)
vis_square(out)
os.chdir("D:/Downloads/tsa_team_project/temporary_result")
write_mask16(marks, "mask")
os.chdir("D:/Downloads/tsa_team_project/temporary_result")
write_mask8(out, "binary")
clear_output(wait=True)

# %% [markdown]
# <MTMarkdownOptions output='html4'>
#     4. Segmentation Evaluation
#     <br>
#     This file is to evaluate our algorithm about segmentation in jaccard coefficient.
# </MTMarkdownOptions>

# %%
def list2pts(ptslist):
    list_y = np.array([ptslist[0]])
    list_x = np.array([ptslist[1]])
    return np.append(list_y, list_x).reshape(2, len(list_y[0])).T

def unique_rows(a):
    a = np.ascontiguousarray(a)
    unique_a = np.unique(a.view([('', a.dtype)]*a.shape[1]))
    return unique_a.view(a.dtype).reshape((unique_a.shape[0], a.shape[1]))

# read image sequence
# The training set locates at "resource/training/01" and "resource/training/02"
# The ground truth of training set locates at "resource/training/GT_01" and 
# "resource/training/GT_02"
# The testing set locates at "resource/testing/01" and "resource/testing/02"

path = os.path.join("resource/training/GT_01")
gts = []
for r,d,f in os.walk(path):
    for files in f:
        if files[-3:].lower()=='tif':
            temp = cv2.imread(os.path.join(r,files), cv2.IMREAD_UNCHANGED)
            gts.append([temp, files[-6:-4]])
print ("number of gts: ", len(gts))

path= os.path.join("resource/training/")
binarymarks = []
for r,d,f in os.walk(path):
    for files in f:
        if files[:4]=='mark':
            temp = cv2.imread(os.path.join(r,files))
            gray = cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY) 
            binarymarks.append([gray, files[-6:-4]])
print ("number of segmentation image: ", len(binarymarks))

jaccards = []

for gt in gts:
    for binarymark in binarymarks:
        if gt[1] == binarymark[1]:
            print ("enter...", gt[1])
            list_pts = set(gt[0][gt[0]>0])
            list_seg = set(binarymark[0][binarymark[0]>0])
            for pt in list_pts:
                for seg in list_seg:
                    pts_gt = np.where(gt[0]==pt)
                    pts_seg = np.where(binarymark[0]==seg)
                    pts_gt = list2pts(pts_gt)

                    pts_seg = list2pts(pts_seg)
                    pts = np.append(pts_gt, pts_seg).reshape(len(pts_gt)+len(pts_seg),2)
                    union_pts = unique_rows(pts)

                    union = float(len(union_pts))
                    intersection = float(len(pts_seg) + len(pts_gt) - len(union_pts))

                    if intersection/union > 0.5:
                        jaccards.append(intersection/union)
clear_output(wait=True)
jaccard = float(sum(jaccards))/max(1, float(len(jaccards)))
print ("jaccard: ", jaccard, "number of Nuclei: ", len(jaccards))
# Out:
# jaccard:  0.0 number of Nuclei:  0

# %% [markdown]
# ## 2. Cell Tracking Part
# <br>
# <MTMarkdownOptions output='html4'>
#     1. Graph Construction
#     <br>
#     This file is to generate a neighboring graph contraction using
#     Delaunary Triangulation.
# </MTMarkdownOptions>

# %%
centroid = None
slope_length = None
class GRAPH():
    '''
    This class contains all the functions needed to compute 
    Delaunary Triangulation.

    '''
    def __init__(self, mark, binary, index):
        '''
        Input: the grayscale mark image with different label on each segments
               the binary image of the mark image
               the index of the image

        '''
        self.mark = mark[index]
        self.binary = binary[index]
              
    def rect_contains(self, rect, point):
        '''
        Check if a point is inside the image

        Input: the size of the image 
               the point that want to test

        Output: if the point is inside the image

        '''
        if point[0] < rect[0] :
            return False
        elif point[1] < rect[1] :
            return False
        elif point[0] > rect[2] :
            return False
        elif point[1] > rect[3] :
            return False
        return True
     
    def draw_point(self, img, p, color ):
        '''
        Draw a point

        '''
        cv2.circle( img, (p[1], p[0]), 2, color, cv2.FILLED, 16, 0 )
     
    def draw_delaunay(self, img, subdiv, delaunay_color):
        '''
        Draw delaunay triangles and store these lines

        Input: the image want to draw
               the set of points: format as cv2.Subdiv2D
               the color want to use

        Output: the slope and length of each line ()

        '''
        triangleList = subdiv.getTriangleList();
        size = img.shape
        r = (0, 0, size[0], size[1])

        slope_length = [[]]
        for i in range(self.mark.max()-1):
            slope_length.append([])

        for t_i, t in enumerate(triangleList):
             
            pt1 = (int(t[0]), int(t[1]))
            pt2 = (int(t[2]), int(t[3]))
            pt3 = (int(t[4]), int(t[5]))
             
            if self.rect_contains(r, pt1) and self.rect_contains(r, pt2) and self.rect_contains(r, pt3):
                
                # draw lines
                cv2.line(img, (pt1[1], pt1[0]), (pt2[1], pt2[0]), delaunay_color, 1, 16, 0)
                cv2.line(img, (pt2[1], pt2[0]), (pt3[1], pt3[0]), delaunay_color, 1, 16, 0)
                cv2.line(img, (pt3[1], pt3[0]), (pt1[1], pt1[0]), delaunay_color, 1, 16, 0)
                
                # store the length of line segments and their slopes
                for p0 in [pt1, pt2, pt3]:
                    for p1 in [pt1, pt2, pt3]:
                        if p0 != p1:
                            temp = self.length_slope(p0, p1)
                            if temp not in slope_length[self.mark[p0]-1]:
                                slope_length[self.mark[p0]-1].append(temp)                

        return slope_length

    def length_slope(self, p0, p1):
        '''
        This function is to compute the length and theta for the given two points.

        Input: two points with the format (y, x)

        '''
        if p1[1]-p0[1]:
            slope = (p1[0]-p0[0]) / (p1[1]-p0[1])
        else:
            slope = 1e10

        length = np.sqrt((p1[0]-p0[0])**2 + (p1[1]-p0[1])**2)

        return length, slope

    def generate_points(self):
        '''
        Find the centroid of each segmentation

        '''
        centroids = []
        label = []
        max_label = self.mark.max()

        for i in range(1, max_label+1):
            img = self.mark.copy()
            img[img!=i] = 0
            if img.sum():
                contours,hierarchy = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_TC89_KCOS)
                m = cv2.moments(contours[0])

                if m['m00']:
                    label.append(i)
                    centroids.append(( int(round(m['m01']/m['m00'])),\
                                       int(round(m['m10']/m['m00'])) ))
                else:
                    label.append(i)
                    centroids.append(( 0,0 ))

        return centroids, label

    def run(self, animate = False):
        '''
        The pipline of graph construction.

        Input: if showing a animation (False for default)

        Output: centroids: # of segments * 2   (y, x)
                slopes and length: # of segments * # of slope_length

        '''
        # Read in the image.
        img_orig = self.binary.copy()
         
        # Rectangle to be used with Subdiv2D
        size = img_orig.shape
        rect = (0, 0, size[0], size[1])
         
        # Create an instance of Subdiv2D
        subdiv = cv2.Subdiv2D(rect);
        
        # find the centroid of each segments
        points, label = self.generate_points()


        # add and sort the centroid to a numpy array for post processing
        centroid = np.zeros((self.mark.max(), 2))
        for p, l in zip(points, label):
            centroid[l-1] = p

        outimg = []
        # Insert points into subdiv
        for idx_p, p in enumerate(points):
            subdiv.insert(p)
             
            # Show animation
            if animate:
                img_copy = img_orig.copy()
                # Draw delaunay triangles
                self.draw_delaunay( img_copy, subdiv, (255, 255, 255));
                outimg.append(img_copy)
                #display_image(img_copy)
                img_copy = cv2.resize(img_copy, (314, 200))
                cv2.imwrite("delaunay_" + str(idx_p).zfill(3) + ".png", img_copy)
                clear_output(wait=True)
                
        # Draw delaunay triangles
        slope_length = self.draw_delaunay( img_orig, subdiv, (255, 255, 255));
     
        # Draw points
        for p in points :
            self.draw_point(img_orig, p, (0,0,255))
        
        # show images
        #if animate:
            #display_image(img_orig)

        print ("length of centroid: ", len(centroid))
        return centroid, slope_length

# %%
# This part is the small test for graph_contruction.py.
# Input:  grayscale marker image
#         binary marker image
# Output: a text file includes the centroid and the length and slope for each neighbor. 

# Build Delaunay Triangulation
global centroid
global slope_length
centroid = []
slope_length = []
for i in range(len(images)):
    print ("  graph_construction: image ", i)
    print (marks)
    print ("max pixel: ", marks[i].max())
    graph = GRAPH(marks, bmarks, i)
    if i == 0:
        tempcentroid, tempslope_length = graph.run(True)
    else:
        tempcentroid, tempslope_length = graph.run()
    centroid.append(tempcentroid)
    slope_length.append(tempslope_length)
    clear_output(wait=True)
print ("finish!")
# Out:
# finish!

# %% [markdown]
# <MTMarkdownOptions output='html4'>
#     2. Matching
#     <br>
#     This file is to match nuclei in two consecutive frames by Phase Controlled Optimal Matching.
#     It includes two part:
# 		1) Dissimilarity measure
# 		2) Matching
# </MTMarkdownOptions>

# %%
import imageio
from pyefd import elliptic_fourier_descriptors

Max_dis = 100000

def write_image(image, title, index, imgformat='.tif'):
    if index < 10:
            name = '00'+str(index)
    else:
        name = '0'+str(index)
    cv2.imwrite(title+name+imgformat, image.astype(np.uint16))

class FEAVECTOR():
    '''
    This class builds a feature vector for each segments.
    The format of each vector is: 
                    v(k,i) = [c(k,i), s(k, i), h(k, i), e(k, i)], where k is the 
                    index of the image (frame) and i is the label of each segment. 

                    c(k,i): the centroid of each segment (y, x);
                    s(k,i): the binary shape of each segment;
                    h(k,i): the intensity distribution (hsitogram) of the segment;
                    e(k,i): the spatial distribution of the segment. Its format is 
                    like (l(k, i, p), theta(k, i, p)), where p represent different
                    line connected with different segment. 

    '''
    def __init__(self, centroid=None, shape=None, histogram=None, spatial=None, \
                       ID=None, start = None, end=None, label=None, ratio=None, area=None, cooc=None):
        self.c = centroid
        self.s = shape
        self.h = histogram
        self.e = spatial
        self.id = ID
        self.start = start
        self.end = end
        self.l = label
        self.a = area
        self.r = ratio
        self.cm = cooc

    def add_id(self, num, index):
        '''
        This function adds cell id for each cell.

        '''
        if index == 0:
            self.id = np.linspace(1, num, num)
        else:
            self.id= np.linspace(-1, -1, num)

    def add_label(self):
        '''
        This function is to add labels for each neclei for post process.

        '''
        self.l = np.linspace(0, 0, len(self.c))

    def set_centroid(self, centroid):
        '''
        This function sets the centroid for all neclei.

        Input: the set of centroid: # of images * # of neclei * 2 (y, x)

        Output: None

        '''
        self.c = centroid

    def set_spatial(self, spatial):
        '''
        This function sets the spatial distrbution for all neclei.

        Input: the set of centroid: # of images * # of neclei * # of line segments (length, slope)

        Output: None

        '''
        self.e = spatial

    def set_shape(self, image, marker):
        '''
        This function sets the binary shape for all necluei.

        Input: the original images: # of images * height * weight
               the labeled images: # of images * nucei's height * nucei's weight ()

        Output: None

        '''
        def boundingbox(image):
            y, x = np.where(image)
            return min(x), min(y), max(x), max(y)

        shape = []

        for label in range(1, marker.max()+1):
            tempimg = marker.copy()
            tempimg[tempimg!=label] = 0
            tempimg[tempimg==label] = 1
            if tempimg.sum():
                minx, miny, maxx, maxy = boundingbox(tempimg)
                shape.append((tempimg[miny:maxy+1, minx:maxx+1], image[miny:maxy+1, minx:maxx+1]))
            else:
                shape.append(([], []))

        self.s = shape

    def set_histogram(self):
        '''
        Note: this function must be implemneted after set_shape().

        '''
        def computehistogram(image):
            h, w = image.shape[:2]
            his = np.zeros((256,1))
            for y in range(h):
                for x in range(w):
                    his[image[y, x], 0] += 1
            return his

        assert self.s != None, "this function must be implemneted after set_shape()."

        his = []

        for j in range(len(self.s)):
            img = self.s[j][1]
            if len(img):
                temphis = computehistogram(img)
                his.append(temphis)
            else:
                his.append(np.zeros((256,1)))

        self.h = his

    def add_efd(self):
        coeffs = []
        for i in range(len(self.s)):
            try:
                _, contours, hierarchy = cv2.findContours(self.s[i][0].astype(np.uint8), 1, 2)
                if not len(contours):
                    coeffs.append(0)
                    continue
                cnt = contours[0]
                if len(cnt) >= 5:
                    contour = []
                    for i in range(len(contours[0])):
                        contour.append(contours[0][i][0])
                    coeffs.append(elliptic_fourier_descriptors(contour, order=10, normalize=False)) 
                else:
                    coeffs.append(0)
            except AttributeError:
                coeffs.append(0)
        self.r = coeffs

    def add_co_occurrence(self, level=10):
        '''
        This funciton is to generate co-occurrence matrix for each cell. The structure of
        output coefficients is:
        [Entropy, Energy, Contrast, Homogeneity]
        '''
        # generate P metrix.
        self.cm = []
        for j in range(len(self.s)):
            if not len(self.s[j][1]):
                p_0 = np.zeros((level,level))
                p_45 = np.zeros((level,level))
                p_90 = np.zeros((level,level))
                p_135 = np.zeros((level,level))
                self.cm.append([np.array([0, 0, 0, 0]),[p_0, p_45, p_90, p_135]])
                continue
            max_p, min_p = np.max(self.s[j][1]), np.min(self.s[j][1])
            range_p = max_p - min_p
            img = np.round((np.asarray(self.s[j][1]).astype(np.float32)-min_p)/range_p*level)
            h, w = img.shape[:2]
            p_0 = np.zeros((level,level))
            p_45 = np.zeros((level,level))
            p_90 = np.zeros((level,level))
            p_135 = np.zeros((level,level))
            for y in range(h):
                for x in range(w):
                    try:
                        p_0[img[y,x],img[y,x+1]] += 1
                    except IndexError:
                        pass
                    try:
                        p_0[img[y,x],img[y,x-1]] += 1
                    except IndexError:
                        pass
                    try:
                        p_90[img[y,x],img[y+1,x]] += 1
                    except IndexError:
                        pass
                    try:
                        p_90[img[y,x],img[y-1,x]] += 1
                    except IndexError:
                        pass
                    try:
                        p_45[img[y,x],img[y+1,x+1]] += 1
                    except IndexError:
                        pass
                    try:
                        p_45[img[y,x],img[y-1,x-1]] += 1
                    except IndexError:
                        pass
                    try:
                        p_135[img[y,x],img[y+1,x-1]] += 1
                    except IndexError:
                        pass
                    try:
                        p_135[img[y,x],img[y-1,x+1]] += 1
                    except IndexError:
                        pass
            Entropy, Energy, Contrast, Homogeneity = 0, 0, 0, 0
            for y in range(10):
                for x in range(10):
                    if 0 not in [p_0[y,x], p_45[y,x], p_90[y,x], p_135[y,x]]:
                        Entropy -= (p_0[y,x]*np.log2(p_0[y,x])+\
                                    p_45[y,x]*np.log2(p_45[y,x])+\
                                    p_90[y,x]*np.log2(p_90[y,x])+\
                                    p_135[y,x]*np.log2(p_135[y,x]))/4
                    else:
                        temp = 0
                        for p in [p_0[y,x], p_45[y,x], p_90[y,x], p_135[y,x]]:
                            if p != 0:
                                temp += p*np.log2(p)
                        Entropy -= temp/4
                    Energy += (p_0[y,x]**2+\
                                p_45[y,x]**2+\
                                p_90[y,x]**2+\
                                p_135[y,x]**2)/4
                    Contrast += (x-y)**2*(p_0[y,x]+\
                                        p_45[y,x]+\
                                        p_90[y,x]+\
                                        p_135[y,x])/4
                    Homogeneity += (p_0[y,x]+\
                                    p_45[y,x]+\
                                    p_90[y,x]+\
                                    p_135[y,x])/(4*(1+abs(x-y)))
            self.cm.append([np.array([Entropy, Energy, Contrast, Homogeneity]),[p_0, p_45, p_90, p_135]])

    def add_area(self):
        area = []
        for i in range(len(self.s)):
            area.append(np.count_nonzero(self.s[i][0]))
        self.a = area

    def generate_vector(self):
        '''
        This function is to convert the vector maxtrics into a list.

        Output: a list of vector: [v0, v1, ....]

        '''
        vector = []
        for i in range(len(self.c)):
                vector.append(FEAVECTOR(centroid=self.c[i],\
                                        shape=self.s[i],\
                                        histogram=self.h[i],\
                                        spatial=self.e[i],\
                                        ID=self.id[i],\
                                        label=self.l[i],\
                                        #ratio=self.r[i],\
                                        area=self.a[i],\
                                        cooc=self.cm[i]))
        return vector



def set_date(vectors):
    '''
    This function is to add the start and end frame of each vector and
    combine the vector with same id.

    Input: the list of vectors in different frames. 

    Output: the list of vectors of all cell with different id. 

    '''
    max_id = 0
    for vector in vectors:
        for pv in vector:
            if pv.id > max_id:
                max_id = pv.id

    output = np.zeros((int(max_id), 4))
    output[:,0] = np.linspace(1, int(max_id), int(max_id)) # set the cell ID
    output[:,1] = len(vectors)
    for frame, vector in enumerate(vectors):
        for pv in vector:
            if output[int(pv.id)-1][1] > frame:     # set the start frame
                output[int(pv.id)-1][1] = frame
            if output[int(pv.id)-1][2] < frame:     # set the end frame
                output[int(pv.id)-1][2] = frame
            output[int(pv.id)-1][3] = pv.l          # set tht cell parent ID

    return output

def write_info(vector, name):
    '''
    This function is to write info. of each vector.

    Input: the list of vector generated by set_date() and 
           the name of output file.

    '''
    with open(name+".txt", "w+") as file:
        for p in vector:
            file.write(str(int(p[0]))+" "+\
                       str(int(p[1]))+" "+\
                       str(int(p[2]))+" "+\
                       str(int(p[3]))+"\n")

# %%
# This part is to test the matching scheme with single image
# Input: the original image;
#        the labeled image;
#        the binary labeled image.

vector = None
# Feature vector construction
global centroid
global slope_length
global vector
vector = []
max_id = 0
for i in range(len(images)):
    print ("  feature vector: image ", i)
    v = FEAVECTOR()
    v.set_centroid(centroid[i])
    v.set_spatial(slope_length[i])
    v.set_shape(enhance_images[i], marks[i])
    v.set_histogram()
    v.add_label()
    v.add_id(marks[i].max(), i)
    #v.add_efd()
    v.add_area()
    v.add_co_occurrence()
    vector.append(v.generate_vector())
    print ("num of nuclei: ", len(vector[i]))
    clear_output(wait=True)

print ("finish")
# Out:
# finish

# %%
all_nums=[]
for i in range(len(vector)):
    all_nums.append(len(vector[i]))
    
plt.plot(all_nums)

# %% [markdown]
# This part is to get the sub-image for each cell and save as file.

# %%
image_size = 70

for i, vt in enumerate(vector):
    counter = 0
    print ("Image: ", i)
    for v in vt:
        h, w = v.s[1].shape[:2]
        extend_x = (image_size - w) // 2
        extend_y = (image_size - h) // 2
        temp = cv2.copyMakeBorder(v.s[1], \
                                  extend_y, (image_size-extend_y-h), \
                                  extend_x, (image_size-extend_x-w), \
                                  cv2.BORDER_CONSTANT, value=0)
        write_mask8(temp, "cell_image"+str(i)+"_", counter)
        counter += 1
        clear_output(wait=True)
print ("finish!")
# Out:
# finish!

# %% [markdown]
# This part is to using ratio of the two axises of inerial as mitosis refinement to mactch cells.

# %%
class SIMPLE_MATCH():
    '''
    This class is simple matching a nucleus into a nucleus in the previous frame by 
    find the nearest neighborhood. 

    '''
    def __init__(self, index0, index1, images, vectors):
        self.v0 = cp.copy(vectors[index0])
        self.v1 = cp.copy(vectors[index1])
        self.i0 = index0
        self.i1 = index1
        self.images = images
        self.vs = cp.copy(vectors)

    def distance_measure(self, pv0, pv1, alpha1=0.5, alpha2=0.25, alpha3=0.25, phase = 1):
        '''
        This function measures the distence of the two given feature vectors. 

        This distance metrics we use is:
                        d(v(k, i), v(k+1, j)) = alpha1 * d(c(k, i), c(k+1, j)) + 
                                                alpha2 * q1 * d(s(k, i), s(k+1, j)) +
                                                alpha3 * q2 * d(h(k, i), h(k+1, j)) +
                                                alpha4 * d(e(k, i), e(k+1, j))
        Input: The two given feature vectors, 
               and the set of parameters.

        Output: the distance of the two given vectors. 

        '''
        def centriod_distance(c0, c1, D=30.):
            dist = np.sqrt((c0[0]-c1[0])**2 + (c0[1]-c1[1])**2)
            return dist/D if dist < D else 1

        def efd_distance(r0, r1, order=8):
            def find_max(max_value, test):
                if max_value < test:
                    return test
                return max_value
            dis = 0
            if type(r0) is not int and type(r1) is not int:
                max_a, max_b, max_c, max_d = 0, 0, 0, 0
                for o in range(order):
                    dis += ((r0[o][0]-r1[o][0])**2+\
                            (r0[o][1]-r1[o][1])**2+\
                            (r0[o][2]-r1[o][2])**2+\
                            (r0[o][3]-r1[o][3])**2)
                    max_a = find_max(max_a, (r0[o][0]-r1[o][0])**2)
                    max_b = find_max(max_b, (r0[o][1]-r1[o][1])**2)
                    max_c = find_max(max_c, (r0[o][2]-r1[o][2])**2)
                    max_d = find_max(max_d, (r0[o][3]-r1[o][3])**2)
                dis /= (order*(max_a+max_b+max_c+max_d))
                if dis > 1.1:
                    print (dis, max_a, max_b, max_c, max_d)
                    raise
            else:
                dis = 1
            return dis

        def cm_distance(cm0, cm1): 
            return ((cm0[0]-cm1[0])**2+\
                   (cm0[1]-cm1[1])**2+\
                   (cm0[2]-cm1[2])**2+\
                   (cm0[3]-cm1[3])**2)/\
                   (max(cm0[0],cm1[0])**2+\
                    max(cm0[1],cm1[1])**2+\
                    max(cm0[2],cm1[2])**2+\
                    max(cm0[3],cm1[3])**2)

        if len(pv0.s[0]) and len(pv1.s[0]):
            dist = 	alpha1 * centriod_distance(pv0.c, pv1.c)+ \
                    alpha2 * efd_distance(pv0.r, pv1.r, order=8) * phase + \
                    alpha3 * cm_distance(pv0.cm[0], pv1.cm[0]) * phase
        else:
            dist = Max_dis

        return dist

    def phase_identify(self, pv1, min_times_MA2ma = 2, RNN=False):
        '''
        Phase identification returns 0 when mitosis appears, vice versa.

        '''
        if not RNN:
            contours, hierarchy = cv2.findContours(pv1.s[0].astype(np.uint8), 1, 2)
            if not len(contours):
                return 1
            cnt = contours[0]
            if len(cnt) >= 5:
                (x,y),(ma,MA),angle = cv2.fitEllipse(cnt)
                if ma and MA/ma > min_times_MA2ma:
                    return 0
                elif not ma and MA:
                    return 0
                else:
                    return 1
            else:
                return 1

        else:
            try: 
                if model.predict([pv1.r.reshape(40)])[-1]:
                    return 0
                else: 
                    return 1
            except AttributeError:
                return 1

    def find_match(self, max_distance=1,a_1=0.5,a_2=0.25,a_3=0.25, rnn=False):
        '''
        This function is to find the nearest neighborhood between two
        successive frame.

        '''
        def centriod_distance(c0, c1, D=30.):
            dist = np.sqrt((c0[0]-c1[0])**2 + (c0[1]-c1[1])**2)
            return dist/D if dist < D else 1

        for i, pv1 in enumerate(self.v1):
            dist = np.ones((len(self.v0), 3), np.float32)*max_distance
            count = 0
            q = self.phase_identify(pv1, 3, RNN=rnn)
            for j, pv0 in enumerate(self.v0):
                if centriod_distance(pv0.c, pv1.c) < 1 and pv0.a:
                    dist[count][0] = self.distance_measure(pv0, pv1, alpha1=a_1, alpha2=a_2, alpha3=a_3, phase=q)
                    dist[count][1] = pv0.l
                    dist[count][2] = pv0.id
                    count += 1

            sort_dist = sorted(dist, key=lambda a_entry: a_entry[0])
            print ("dis: ", sort_dist[0][0])
            if sort_dist[0][0] < max_distance:
                self.v1[i].l = sort_dist[0][1]
                self.v1[i].id = sort_dist[0][2]

    def mitosis_refine(self, rnn=False):
        '''
        This function is to find died cell due to the by mitosis. 

        '''
        def find_sibling(pv0):
            '''
            This function is to find sibling cells according to the centroid of
            pv0. The criteria of sibling is:
                    1. the jaccard cooeficient of the two cells is above 0.5
                    2. the sum of the two areas should in the range [A, 2.5A], where
                       A is the area of the pv0
                    3. the position of the two cells should be not larger than 20 pixels.

            Input: pv0: the parent cell that you want to find siblings;

            Output: the index of the siblings.

            '''
            def maxsize_image(image1, image2):
                y1, x1 = np.where(image1)
                y2, x2 = np.where(image2)
                return min(min(x1), min(x2)), min(min(y1), min(y2)), \
                       max(max(x1), max(x2)), max(max(y1), max(y2)),

            def symmetry(image, shape):
                h, w = image.shape[:2] 
                newimg = np.zeros(shape)
                newimg[:h, :w] = image
                v = float(shape[0] - h)/2.
                u = float(shape[1] - w)/2.
                M = np.float32([[1,0,u],[0,1,v]])
                return cv2.warpAffine(newimg,M,(shape[1],shape[0]))

            def jaccard(s0, s1):
                minx, miny, maxx, maxy = maxsize_image(s0, s1)
                height = maxy - miny + 1
                width = maxx - minx + 1

                img0 = symmetry(s0, (height, width))
                img1 = symmetry(s1, (height, width))

                num = 0.
                deno = 0.
                for y in range(height):
                    for x in range(width):
                        if img0[y, x] and img1[y, x]:
                            num += 1
                        if img0[y, x] or img1[y, x]:
                            deno += 1

                return num/deno

            sibling_cand = []
            for i, pv1 in enumerate(self.v1): 
                if np.linalg.norm(pv1.c-pv0.c) < 50:
                    sibling_cand.append([pv1, i])

            sibling_pair = []
            area = pv0.s[0].sum()
            jaccard_value = []
            for sibling0 in sibling_cand:
                for sibling1 in sibling_cand:
                    if (sibling1[0].c != sibling0[0].c).all():
                        sum_area = sibling1[0].s[0].sum()+sibling0[0].s[0].sum()
                        similarity = jaccard(sibling0[0].s[0], sibling1[0].s[0])
                        if similarity > 0.4 and (sum_area > 2*area):
                            sibling_pair.append([sibling0, sibling1])
                            jaccard_value.append(similarity)
            if len(jaccard_value):
                return sibling_pair[np.argmax(jaccard_value)]
            else:
                return 0

        v1_ids = []
        for pv1 in self.v1:
            v1_ids.append(pv1.id)

        for i, pv0 in enumerate(self.v0):
            if pv0.id not in v1_ids and len(pv0.s[0]) and self.phase_identify(pv0, 3, RNN=rnn):
                sibling = find_sibling(pv0)
                if sibling:
                    [s0, s1] = sibling
                    if s0[0].l==0 and s1[0].l==0 and \
                       s0[0].id==-1 and s1[0].id==-1:
                        self.v1[s0[1]].l = pv0.id
                        self.v1[s1[1]].l = pv0.id

        return self.v1

    def match_missing(self, mask, max_frame = 1, max_distance = 10, min_shape_similarity = 0.6):
        '''
        This function is to match the cells that didn't show in the last frame caused by 
        program fault. In order to match them, we need to seach the cell in the previous 
        frame with in the certain range and with similar shape.  

        '''
        def centriod_distance(c0, c1):
            dist = np.sqrt((c0[0]-c1[0])**2 + (c0[1]-c1[1])**2)
            return dist

        def maxsize_image(image1, image2):
            y1, x1 = np.where(image1)
            y2, x2 = np.where(image2)
            return min(min(x1), min(x2)), min(min(y1), min(y2)), \
                   max(max(x1), max(x2)), max(max(y1), max(y2)),

        def symmetry(image, shape):
            h, w = image.shape[:2] 
            newimg = np.zeros(shape)
            newimg[:h, :w] = image
            v = float(shape[0] - h)/2.
            u = float(shape[1] - w)/2.
            M = np.float32([[1,0,u],[0,1,v]])
            return cv2.warpAffine(newimg,M,(shape[1],shape[0]))

        def shape_similarity(s0, s1):
            if len(s0) and len(s1):
                minx, miny, maxx, maxy = maxsize_image(s0, s1)
                height = maxy - miny + 1
                width = maxx - minx + 1

                img0 = symmetry(s0, (height, width))
                img1 = symmetry(s1, (height, width))

                num = 0.
                deno = 0.
                for y in range(height):
                    for x in range(width):
                        if img0[y, x] and img1[y, x]:
                            num += 1
                        if img0[y, x] or img1[y, x]:
                            deno += 1
                return num/deno

            else:
                return 0.

        def add_marker(index_find, index_new, pv0_id):
            temp = mask[index_new]
            find = mask[index_find]
            temp[find==pv0_id] = pv0_id
            return temp

        for i, pv1 in enumerate(self.v1):
            if pv1.id == -1:
                for index in range(1, max_frame+1):
                    if self.i0-index >= 0:
                        vt = self.vs[self.i0-index]
                        for pv0 in vt:
                            if centriod_distance(pv0.c, pv1.c) < max_distance and \
                                shape_similarity(pv0.s[0], pv1.s[0]) > min_shape_similarity:
                                self.v1[i].id = pv0.id
                                self.v1[i].l = pv0.l
                                print ("missing in frame: ", self.i1, "find in frame: ", \
                                       self.i0-index, "ID: ", pv0.id, " at: ", pv0.c)
                                for i in range(self.i0-index+1, self.i1):
                                    mask[i] = add_marker(self.i0-index, i, pv0.id)
        return mask

    def new_id(self, vectors):
        '''
        This function is to add new labels for the necles that are marked as -1.


        '''
        def find_max_id(vectors):
            max_id = 0
            for vt in vectors:
                for pt in vt:
                    if pt.id > max_id:
                        max_id = pt.id 
            return max_id
        max_id = find_max_id(self.vs)
        max_id += 1
        for i, pv1 in enumerate(self.v1):
            if pv1.id == -1:
                self.v1[i].id = max_id
                max_id += 1

    def generate_mask(self, marker, index, isfinal=False):
        '''
        This function is to generate a 16-bit image as mask image. 

        '''
        h, w = marker.shape[:2]
        mask = np.zeros((h, w), np.uint16)
        pts = list(set(marker[marker>0]))
        if not isfinal:
            assert len(pts)==len(self.v0), 'len(pts): %s != len(self.v0): %s' % (len(pts), len(self.v0))
            for pt, pv in zip(pts, self.v0):
                mask[marker==pt] = pv.id

        else:
            assert len(pts)==len(self.v1), 'len(pts): %s != len(self.v0): %s' % (len(pts), len(self.v1))
            for pt, pv in zip(pts, self.v1):
                mask[marker==pt] = pv.id

        os.chdir(".")
        write_mask16(mask, "mask", index)
        os.chdir(os.pardir)
        return mask	

    def return_vectors(self):
        '''
        This function is to return the vectors that we have already 
        changed.

        Output: the vectors from the k+1 frame.

        '''	
        return self.v1

# %%
import copy as cp

mask = []
temp_vector = cp.deepcopy(vector)

# Feature matching
for i in range(len(images)-1):
    print ("  Feature matching: image ", i)
    m = SIMPLE_MATCH(i,i+1,[images[i], images[i+1]], temp_vector)
    mask.append(m.generate_mask(marks[i], i))
    #m.find_match(0.7,0.7,0.15,0.15)
    temp_vector[i+1] = m.mitosis_refine()
    m.new_id(temp_vector)
    temp_vector[i+1] = m.return_vectors()
    clear_output(wait=True)

print ("  Feature matching: image ", i+1)
mask.append(m.generate_mask(marks[i+1], i+1, True))
os.chdir(".")
cells = set_date(temp_vector)
write_info(cells, "res_track")
print ("finish!")
# Out:
#   Feature matching: image  91
# finish!

# %% [markdown]
# This part generates the final marked result in "gif".

# %%
# write gif image showing the final result
def find_max_id(temp_vector):
    max_id = 0
    for pv in temp_vector:
        for p in pv:
            if p.id > max_id:
                max_id = p.id
    return max_id

# This part is to mark the result in the normolized image and 
# write the gif image.
max_id = find_max_id(temp_vector)
colors = [np.random.randint(0, 255, size=int(max_id)),\
          np.random.randint(0, 255, size=int(max_id)),\
          np.random.randint(0, 255, size=int(max_id))]
font = cv2.FONT_HERSHEY_SIMPLEX 
selecy_id = 9
enhance_imgs = []
for i, m in enumerate(mask):
    print ("  write the gif image: image ", i)
    enhance_imgs.append(cv2.cvtColor(enhance_images[i],cv2.COLOR_GRAY2RGB))
    for pv in temp_vector[i]:
        center = pv.c
        if not pv.l:
            color = (colors[0][int(pv.id)-1],\
                     colors[1][int(pv.id)-1],\
                     colors[2][int(pv.id)-1],)
        else:
            color = (colors[0][int(pv.l)-1],\
                     colors[1][int(pv.l)-1],\
                     colors[2][int(pv.l)-1],)

        if m[int(center[0]), int(center[1])]:
            enhance_imgs[i][m==pv.id] = color
            cv2.putText(enhance_imgs[i],\
                        str(int(pv.id)),(int(pv.c[1]), \
                        int(pv.c[0])), 
                        font, 0.5,\
                        (255,255,255),1)
    clear_output(wait=True)
os.chdir("D:/Downloads/tsa_team_project/result")
imageio.mimsave('mitosis_final.gif', enhance_imgs, duration=0.6)
print ("finish!")
# Out:
# finish!

# %%
temp_vector
# Out:
# [[<__main__.FEAVECTOR at 0x230ef38afa0>,
#   <__main__.FEAVECTOR at 0x230ef38a640>,
#   <__main__.FEAVECTOR at 0x230f3f87bb0>,
#   <__main__.FEAVECTOR at 0x230f3f87df0>,
#   <__main__.FEAVECTOR at 0x22d9fbdddf0>,
#   <__main__.FEAVECTOR at 0x22d9fbdd2b0>,
#   <__main__.FEAVECTOR at 0x22d9fbddd90>,
#   <__main__.FEAVECTOR at 0x22d9fbdd700>,
#   <__main__.FEAVECTOR at 0x230f4122610>,
#   <__main__.FEAVECTOR at 0x230f4122b20>,
#   <__main__.FEAVECTOR at 0x230f17f9ee0>,
#   <__main__.FEAVECTOR at 0x230f17f9f10>,
#   <__main__.FEAVECTOR at 0x22df61a1130>,
#   <__main__.FEAVECTOR at 0x22df61a1910>,
#   <__main__.FEAVECTOR at 0x22df61a1850>,
#   <__main__.FEAVECTOR at 0x22df61a16d0>,
#   <__main__.FEAVECTOR at 0x22df61a1610>,
#   <__main__.FEAVECTOR at 0x22df61a19d0>,
#   <__main__.FEAVECTOR at 0x22df61a1070>,
#   <__main__.FEAVECTOR at 0x230f40552b0>,
#   <__main__.FEAVECTOR at 0x230f4055250>,
#   <__main__.FEAVECTOR at 0x230f40552e0>,
#   <__main__.FEAVECTOR at 0x230f4055190>,
#   <__main__.FEAVECTOR at 0x230f40551f0>,
#   <__main__.FEAVECTOR at 0x230f40550d0>,
#   <__main__.FEAVECTOR at 0x230f4055130>,
#   <__main__.FEAVECTOR at 0x230f4055070>,
#   <__main__.FEAVECTOR at 0x230f4055a90>,
#   <__main__.FEAVECTOR at 0x230f4055490>,
#   <__main__.FEAVECTOR at 0x230f4055430>,
#   <__main__.FEAVECTOR at 0x230f4055550>,
#   <__main__.FEAVECTOR at 0x230f40554f0>,
#   <__main__.FEAVECTOR at 0x230f40555b0>,
#   <__main__.FEAVECTOR at 0x230f4055670>,
#   <__main__.FEAVECTOR at 0x230f40556d0>,
#   <__main__.FEAVECTOR at 0x230f4055730>,
#   <__main__.FEAVECTOR at 0x230f4055610>,
#   <__main__.FEAVECTOR at 0x230f4055a00>,
#   <__main__.FEAVECTOR at 0x230f40559a0>,
#   <__main__.FEAVECTOR at 0x230f4055a60>,
#   <__main__.FEAVECTOR at 0x230f4055940>,
#   <__main__.FEAVECTOR at 0x230f40558e0>,
#   <__main__.FEAVECTOR at 0x230f4055820>,
#   <__main__.FEAVECTOR at 0x230f40557c0>,
#   <__main__.FEAVECTOR at 0x230f4055880>,
#   <__main__.FEAVECTOR at 0x230f4055b20>,
#   <__main__.FEAVECTOR at 0x230f4055ac0>,
#   <__main__.FEAVECTOR at 0x230f4055b80>,
#   <__main__.FEAVECTOR at 0x230f4055be0>,
#   <__main__.FEAVECTOR at 0x230f4055c40>,
#   <__main__.FEAVECTOR at 0x230f4055d00>,
#   <__main__.FEAVECTOR at 0x230f4055d60>,
#   <__main__.FEAVECTOR at 0x230f4055ca0>,
#   <__main__.FEAVECTOR at 0x230f4055e20>,
#   <__main__.FEAVECTOR at 0x230f4055e80>,
#   <__main__.FEAVECTOR at 0x230f4055dc0>,
#   <__main__.FEAVECTOR at 0x230f4055ee0>,
#   <__main__.FEAVECTOR at 0x230f4055f40>,
#   <__main__.FEAVECTOR at 0x230f4055fa0>,
#   <__main__.FEAVECTOR at 0x230f404a040>,
#   <__main__.FEAVECTOR at 0x230f404a0a0>,
#   <__main__.FEAVECTOR at 0x230f404a160>,
#   <__main__.FEAVECTOR at 0x230f404a100>,
#   <__main__.FEAVECTOR at 0x230f404a1c0>,
#   <__main__.FEAVECTOR at 0x230f404a220>,
#   <__main__.FEAVECTOR at 0x230f404a2e0>,
#   <__main__.FEAVECTOR at 0x230f404a340>,
#   <__main__.FEAVECTOR at 0x230f404a3a0>,
#   <__main__.FEAVECTOR at 0x230f404a400>,
#   <__main__.FEAVECTOR at 0x230f404a460>,
#   <__main__.FEAVECTOR at 0x230f404a280>,
#   <__main__.FEAVECTOR at 0x230f404a520>,
#   <__main__.FEAVECTOR at 0x230f404a4c0>,
#   <__main__.FEAVECTOR at 0x230f404a5e0>,
#   <__main__.FEAVECTOR at 0x230f404a580>,
#   <__main__.FEAVECTOR at 0x230f404a640>,
#   <__main__.FEAVECTOR at 0x230f404a6a0>,
#   <__main__.FEAVECTOR at 0x230f404a790>],
#  [<__main__.FEAVECTOR at 0x230f404a7f0>,
#   <__main__.FEAVECTOR at 0x230f404a850>,
#   <__main__.FEAVECTOR at 0x230f404a8b0>,
#   <__main__.FEAVECTOR at 0x230f404a730>,
#   <__main__.FEAVECTOR at 0x230f404a970>,
#   <__main__.FEAVECTOR at 0x230f404a9d0>,
#   <__main__.FEAVECTOR at 0x230f404a910>,
#   <__main__.FEAVECTOR at 0x230f404aa30>,
#   <__main__.FEAVECTOR at 0x230f404aa90>,
#   <__main__.FEAVECTOR at 0x230f404aaf0>,
#   <__main__.FEAVECTOR at 0x230f404ab50>,
#   <__main__.FEAVECTOR at 0x230f404abb0>,
#   <__main__.FEAVECTOR at 0x230f404ac70>,
#   <__main__.FEAVECTOR at 0x230f404acd0>,
#   <__main__.FEAVECTOR at 0x230f404ad30>,
#   <__main__.FEAVECTOR at 0x230f404ac10>,
#   <__main__.FEAVECTOR at 0x230f404adf0>,
#   <__main__.FEAVECTOR at 0x230f404ae50>,
#   <__main__.FEAVECTOR at 0x230f404aeb0>,
#   <__main__.FEAVECTOR at 0x230f404ad90>,
#   <__main__.FEAVECTOR at 0x230f404af70>,
#   <__main__.FEAVECTOR at 0x230f404af10>,
#   <__main__.FEAVECTOR at 0x230f404e280>,
#   <__main__.FEAVECTOR at 0x230f404e250>,
#   <__main__.FEAVECTOR at 0x230f404e040>,
#   <__main__.FEAVECTOR at 0x230f404e0a0>,
#   <__main__.FEAVECTOR at 0x230f404e130>,
#   <__main__.FEAVECTOR at 0x230f404e220>,
#   <__main__.FEAVECTOR at 0x230f404e0d0>,
#   <__main__.FEAVECTOR at 0x230f404e1c0>,
#   <__main__.FEAVECTOR at 0x230f404e6d0>,
#   <__main__.FEAVECTOR at 0x230f404e640>,
#   <__main__.FEAVECTOR at 0x230f404e310>,
#   <__main__.FEAVECTOR at 0x230f404e3d0>,
#   <__main__.FEAVECTOR at 0x230f404e460>,
#   <__main__.FEAVECTOR at 0x230f404e400>,
#   <__main__.FEAVECTOR at 0x230f404e340>,
#   <__main__.FEAVECTOR at 0x230f404e520>,
#   <__main__.FEAVECTOR at 0x230f404e5b0>,
#   <__main__.FEAVECTOR at 0x230f404e5e0>,
#   <__main__.FEAVECTOR at 0x230f404ea60>,
#   <__main__.FEAVECTOR at 0x230f404eaf0>,
#   <__main__.FEAVECTOR at 0x230f404e730>,
#   <__main__.FEAVECTOR at 0x230f404e370>,
#   <__main__.FEAVECTOR at 0x230f404e760>,
#   <__main__.FEAVECTOR at 0x230f404e880>,
#   <__main__.FEAVECTOR at 0x230f404e820>,
#   <__main__.FEAVECTOR at 0x230f404e7f0>,
#   <__main__.FEAVECTOR at 0x230f404e9d0>,
#   <__main__.FEAVECTOR at 0x230f404ea00>,
#   <__main__.FEAVECTOR at 0x230f404e940>,
#   <__main__.FEAVECTOR at 0x230f404eee0>,
#   <__main__.FEAVECTOR at 0x230f404ef70>,
#   <__main__.FEAVECTOR at 0x230f404eb50>,
#   <__main__.FEAVECTOR at 0x230f404e790>,
#   <__main__.FEAVECTOR at 0x230f404ec10>,
#   <__main__.FEAVECTOR at 0x230f404eca0>,
#   <__main__.FEAVECTOR at 0x230f404eb80>,
#   <__main__.FEAVECTOR at 0x230f404ed60>,
#   <__main__.FEAVECTOR at 0x230f404ec40>,
#   <__main__.FEAVECTOR at 0x230f404edf0>,
#   <__main__.FEAVECTOR at 0x230f404ee50>,
#   <__main__.FEAVECTOR at 0x230f404ee20>,
#   <__main__.FEAVECTOR at 0x230f404ebb0>,
#   <__main__.FEAVECTOR at 0x230f4038070>,
#   <__main__.FEAVECTOR at 0x230f40380d0>,
#   <__main__.FEAVECTOR at 0x230f4038130>,
#   <__main__.FEAVECTOR at 0x230f4038040>,
#   <__main__.FEAVECTOR at 0x230f4038190>,
#   <__main__.FEAVECTOR at 0x230f40381f0>,
#   <__main__.FEAVECTOR at 0x230f40382b0>,
#   <__main__.FEAVECTOR at 0x230f4038250>,
#   <__main__.FEAVECTOR at 0x230f4038310>,
#   <__main__.FEAVECTOR at 0x230f40383d0>,
#   <__main__.FEAVECTOR at 0x230f4038370>,
#   <__main__.FEAVECTOR at 0x230f4038430>,
#   <__main__.FEAVECTOR at 0x230f40384f0>,
#   <__main__.FEAVECTOR at 0x230f4038490>,
#   <__main__.FEAVECTOR at 0x230f4038550>,
#   <__main__.FEAVECTOR at 0x230f4038610>,
#   <__main__.FEAVECTOR at 0x230f40385b0>,
#   <__main__.FEAVECTOR at 0x230f4038670>,
#   <__main__.FEAVECTOR at 0x230f40386d0>,
#   <__main__.FEAVECTOR at 0x230f4038790>],
#  [<__main__.FEAVECTOR at 0x230f40387f0>,
#   <__main__.FEAVECTOR at 0x230f4038850>,
#   <__main__.FEAVECTOR at 0x230f40388b0>,
#   <__main__.FEAVECTOR at 0x230f4038730>,
#   <__main__.FEAVECTOR at 0x230f4038970>,
#   <__main__.FEAVECTOR at 0x230f40389d0>,
#   <__main__.FEAVECTOR at 0x230f4038910>,
#   <__main__.FEAVECTOR at 0x230f4038a90>,
#   <__main__.FEAVECTOR at 0x230f4038af0>,
#   <__main__.FEAVECTOR at 0x230f4038a30>,
#   <__main__.FEAVECTOR at 0x230f4038b50>,
#   <__main__.FEAVECTOR at 0x230f4038c10>,
#   <__main__.FEAVECTOR at 0x230f4038c70>,
#   <__main__.FEAVECTOR at 0x230f4038cd0>,
#   <__main__.FEAVECTOR at 0x230f4038d30>,
#   <__main__.FEAVECTOR at 0x230f4038bb0>,
#   <__main__.FEAVECTOR at 0x230f4038df0>,
#   <__main__.FEAVECTOR at 0x230f4038d90>,
#   <__main__.FEAVECTOR at 0x230f4038eb0>,
#   <__main__.FEAVECTOR at 0x230f4038f10>,
#   <__main__.FEAVECTOR at 0x230f4038f70>,
#   <__main__.FEAVECTOR at 0x230f4038e50>,
#   <__main__.FEAVECTOR at 0x230f4065070>,
#   <__main__.FEAVECTOR at 0x230f40650d0>,
#   <__main__.FEAVECTOR at 0x230f4065130>,
#   <__main__.FEAVECTOR at 0x230f4065190>,
#   <__main__.FEAVECTOR at 0x230f40651f0>,
#   <__main__.FEAVECTOR at 0x230f4065250>,
#   <__main__.FEAVECTOR at 0x230f4065040>,
#   <__main__.FEAVECTOR at 0x230f4065310>,
#   <__main__.FEAVECTOR at 0x230f4065370>,
#   <__main__.FEAVECTOR at 0x230f40652b0>,
#   <__main__.FEAVECTOR at 0x230f40653d0>,
#   <__main__.FEAVECTOR at 0x230f4065490>,
#   <__main__.FEAVECTOR at 0x230f4065430>,
#   <__main__.FEAVECTOR at 0x230f40654f0>,
#   <__main__.FEAVECTOR at 0x230f4065550>,
#   <__main__.FEAVECTOR at 0x230f4065610>,
#   <__main__.FEAVECTOR at 0x230f40655b0>,
#   <__main__.FEAVECTOR at 0x230f4065670>,
#   <__main__.FEAVECTOR at 0x230f4065730>,
#   <__main__.FEAVECTOR at 0x230f40656d0>,
#   <__main__.FEAVECTOR at 0x230f40657f0>,
#   <__main__.FEAVECTOR at 0x230f4065790>,
#   <__main__.FEAVECTOR at 0x230f4065850>,
#   <__main__.FEAVECTOR at 0x230f4065910>,
#   <__main__.FEAVECTOR at 0x230f4065970>,
#   <__main__.FEAVECTOR at 0x230f40658b0>,
#   <__main__.FEAVECTOR at 0x230f40659d0>,
#   <__main__.FEAVECTOR at 0x230f4065a90>,
#   <__main__.FEAVECTOR at 0x230f4065af0>,
#   <__main__.FEAVECTOR at 0x230f4065a30>,
#   <__main__.FEAVECTOR at 0x230f4065bb0>,
#   <__main__.FEAVECTOR at 0x230f4065b50>,
#   <__main__.FEAVECTOR at 0x230f4065c10>,
#   <__main__.FEAVECTOR at 0x230f4065c70>,
#   <__main__.FEAVECTOR at 0x230f4065d30>,
#   <__main__.FEAVECTOR at 0x230f4065d90>,
#   <__main__.FEAVECTOR at 0x230f4065cd0>,
#   <__main__.FEAVECTOR at 0x230f4065df0>,
#   <__main__.FEAVECTOR at 0x230f4065eb0>,
#   <__main__.FEAVECTOR at 0x230f4065e50>,
#   <__main__.FEAVECTOR at 0x230f4065f70>,
#   <__main__.FEAVECTOR at 0x230f4065fd0>,
#   <__main__.FEAVECTOR at 0x230f4072040>,
#   <__main__.FEAVECTOR at 0x230f40720d0>,
#   <__main__.FEAVECTOR at 0x230f4072130>,
#   <__main__.FEAVECTOR at 0x230f4072070>,
#   <__main__.FEAVECTOR at 0x230f4072190>,
#   <__main__.FEAVECTOR at 0x230f40721f0>,
#   <__main__.FEAVECTOR at 0x230f40722b0>,
#   <__main__.FEAVECTOR at 0x230f4072310>,
#   <__main__.FEAVECTOR at 0x230f4072250>,
#   <__main__.FEAVECTOR at 0x230f4072370>,
#   <__main__.FEAVECTOR at 0x230f4072430>,
#   <__main__.FEAVECTOR at 0x230f40723d0>,
#   <__main__.FEAVECTOR at 0x230f40724f0>,
#   <__main__.FEAVECTOR at 0x230f4072550>,
#   <__main__.FEAVECTOR at 0x230f40725b0>,
#   <__main__.FEAVECTOR at 0x230f4072610>,
#   <__main__.FEAVECTOR at 0x230f4072670>,
#   <__main__.FEAVECTOR at 0x230f4072490>,
#   <__main__.FEAVECTOR at 0x230f40726d0>,
#   <__main__.FEAVECTOR at 0x230f4072790>,
#   <__main__.FEAVECTOR at 0x230f4072730>,
#   <__main__.FEAVECTOR at 0x230f40727f0>,
#   <__main__.FEAVECTOR at 0x230f4072850>,
#   <__main__.FEAVECTOR at 0x230f40728b0>],
#  [<__main__.FEAVECTOR at 0x230f4072970>,
#   <__main__.FEAVECTOR at 0x230f4072910>,
#   <__main__.FEAVECTOR at 0x230f4072a30>,
#   <__main__.FEAVECTOR at 0x230f4072a90>,
#   <__main__.FEAVECTOR at 0x230f4072af0>,
#   <__main__.FEAVECTOR at 0x230f40729d0>,
#   <__main__.FEAVECTOR at 0x230f4072bb0>,
#   <__main__.FEAVECTOR at 0x230f4072c10>,
#   <__main__.FEAVECTOR at 0x230f4072c70>,
#   <__main__.FEAVECTOR at 0x230f4072b50>,
#   <__main__.FEAVECTOR at 0x230f4072d30>,
#   <__main__.FEAVECTOR at 0x230f4072cd0>,
#   <__main__.FEAVECTOR at 0x230f4072df0>,
#   <__main__.FEAVECTOR at 0x230f4072e50>,
#   <__main__.FEAVECTOR at 0x230f4072eb0>,
#   <__main__.FEAVECTOR at 0x230f4072d90>,
#   <__main__.FEAVECTOR at 0x230f4072f70>,
#   <__main__.FEAVECTOR at 0x230f4072f10>,
#   <__main__.FEAVECTOR at 0x230f407d070>,
#   <__main__.FEAVECTOR at 0x230f407d0d0>,
#   <__main__.FEAVECTOR at 0x230f407d130>,
#   <__main__.FEAVECTOR at 0x230f407d040>,
#   <__main__.FEAVECTOR at 0x230f407d190>,
#   <__main__.FEAVECTOR at 0x230f407d1f0>,
#   <__main__.FEAVECTOR at 0x230f407d2b0>,
#   <__main__.FEAVECTOR at 0x230f407d310>,
#   <__main__.FEAVECTOR at 0x230f407d250>,
#   <__main__.FEAVECTOR at 0x230f407d370>,
#   <__main__.FEAVECTOR at 0x230f407d3d0>,
#   <__main__.FEAVECTOR at 0x230f407d490>,
#   <__main__.FEAVECTOR at 0x230f407d4f0>,
#   <__main__.FEAVECTOR at 0x230f407d550>,
#   <__main__.FEAVECTOR at 0x230f407d430>,
#   <__main__.FEAVECTOR at 0x230f407d610>,
#   <__main__.FEAVECTOR at 0x230f407d5b0>,
#   <__main__.FEAVECTOR at 0x230f407d670>,
#   <__main__.FEAVECTOR at 0x230f407d730>,
#   <__main__.FEAVECTOR at 0x230f407d790>,
#   <__main__.FEAVECTOR at 0x230f407d6d0>,
#   <__main__.FEAVECTOR at 0x230f407d7f0>,
#   <__main__.FEAVECTOR at 0x230f407d850>,
#   <__main__.FEAVECTOR at 0x230f407d8b0>,
#   <__main__.FEAVECTOR at 0x230f407d910>,
#   <__main__.FEAVECTOR at 0x230f407d9d0>,
#   <__main__.FEAVECTOR at 0x230f407da30>,
#   <__main__.FEAVECTOR at 0x230f407d970>,
#   <__main__.FEAVECTOR at 0x230f407da90>,
#   <__main__.FEAVECTOR at 0x230f407db50>,
#   <__main__.FEAVECTOR at 0x230f407dbb0>,
#   <__main__.FEAVECTOR at 0x230f407dc10>,
#   <__main__.FEAVECTOR at 0x230f407daf0>,
#   <__main__.FEAVECTOR at 0x230f407dcd0>,
#   <__main__.FEAVECTOR at 0x230f407dc70>,
#   <__main__.FEAVECTOR at 0x230f407dd30>,
#   <__main__.FEAVECTOR at 0x230f407dd90>,
#   <__main__.FEAVECTOR at 0x230f407de50>,
#   <__main__.FEAVECTOR at 0x230f407ddf0>,
#   <__main__.FEAVECTOR at 0x230f407deb0>,
#   <__main__.FEAVECTOR at 0x230f407df70>,
#   <__main__.FEAVECTOR at 0x230f407dfd0>,
#   <__main__.FEAVECTOR at 0x230f4089040>,
#   <__main__.FEAVECTOR at 0x230f4089070>,
#   <__main__.FEAVECTOR at 0x230f4089130>,
#   <__main__.FEAVECTOR at 0x230f40890d0>,
#   <__main__.FEAVECTOR at 0x230f40891f0>,
#   <__main__.FEAVECTOR at 0x230f4089190>,
#   <__main__.FEAVECTOR at 0x230f40892b0>,
#   <__main__.FEAVECTOR at 0x230f4089310>,
#   <__main__.FEAVECTOR at 0x230f4089370>,
#   <__main__.FEAVECTOR at 0x230f40893d0>,
#   <__main__.FEAVECTOR at 0x230f4089430>,
#   <__main__.FEAVECTOR at 0x230f4089250>,
#   <__main__.FEAVECTOR at 0x230f4089490>,
#   <__main__.FEAVECTOR at 0x230f40894f0>,
#   <__main__.FEAVECTOR at 0x230f40895b0>,
#   <__main__.FEAVECTOR at 0x230f4089610>,
#   <__main__.FEAVECTOR at 0x230f4089670>,
#   <__main__.FEAVECTOR at 0x230f40896d0>,
#   <__main__.FEAVECTOR at 0x230f4089730>,
#   <__main__.FEAVECTOR at 0x230f4089790>,
#   <__main__.FEAVECTOR at 0x230f4089550>,
#   <__main__.FEAVECTOR at 0x230f40897f0>,
#   <__main__.FEAVECTOR at 0x230f4089850>,
#   <__main__.FEAVECTOR at 0x230f4089910>,
#   <__main__.FEAVECTOR at 0x230f4089970>,
#   <__main__.FEAVECTOR at 0x230f40898b0>,
#   <__main__.FEAVECTOR at 0x230f40899d0>],
#  [<__main__.FEAVECTOR at 0x230f4089a30>,
#   <__main__.FEAVECTOR at 0x230f4089af0>,
#   <__main__.FEAVECTOR at 0x230f4089a90>,
#   <__main__.FEAVECTOR at 0x230f4089b50>,
#   <__main__.FEAVECTOR at 0x230f4089c10>,
#   <__main__.FEAVECTOR at 0x230f4089bb0>,
#   <__main__.FEAVECTOR at 0x230f4089cd0>,
#   <__main__.FEAVECTOR at 0x230f4089c70>,
#   <__main__.FEAVECTOR at 0x230f4089d90>,
#   <__main__.FEAVECTOR at 0x230f4089df0>,
#   <__main__.FEAVECTOR at 0x230f4089d30>,
#   <__main__.FEAVECTOR at 0x230f4089e50>,
#   <__main__.FEAVECTOR at 0x230f4089eb0>,
#   <__main__.FEAVECTOR at 0x230f4089f10>,
#   <__main__.FEAVECTOR at 0x230f4089fd0>,
#   <__main__.FEAVECTOR at 0x230f4095040>,
#   <__main__.FEAVECTOR at 0x230f4095070>,
#   <__main__.FEAVECTOR at 0x230f40950d0>,
#   <__main__.FEAVECTOR at 0x230f4095130>,
#   <__main__.FEAVECTOR at 0x230f4095190>,
#   <__main__.FEAVECTOR at 0x230f4095250>,
#   <__main__.FEAVECTOR at 0x230f40952b0>,
#   <__main__.FEAVECTOR at 0x230f4095310>,
#   <__main__.FEAVECTOR at 0x230f4095370>,
#   <__main__.FEAVECTOR at 0x230f40951f0>,
#   <__main__.FEAVECTOR at 0x230f40953d0>,
#   <__main__.FEAVECTOR at 0x230f4095430>,
#   <__main__.FEAVECTOR at 0x230f40954f0>,
#   <__main__.FEAVECTOR at 0x230f4095490>,
#   <__main__.FEAVECTOR at 0x230f40955b0>,
#   <__main__.FEAVECTOR at 0x230f4095610>,
#   <__main__.FEAVECTOR at 0x230f4095670>,
#   <__main__.FEAVECTOR at 0x230f4095550>,
#   <__main__.FEAVECTOR at 0x230f40956d0>,
#   <__main__.FEAVECTOR at 0x230f4095790>,
#   <__main__.FEAVECTOR at 0x230f40957f0>,
#   <__main__.FEAVECTOR at 0x230f4095730>,
#   <__main__.FEAVECTOR at 0x230f40958b0>,
#   <__main__.FEAVECTOR at 0x230f4095850>,
#   <__main__.FEAVECTOR at 0x230f4095910>,
#   <__main__.FEAVECTOR at 0x230f40959d0>,
#   <__main__.FEAVECTOR at 0x230f4095970>,
#   <__main__.FEAVECTOR at 0x230f4095a30>,
#   <__main__.FEAVECTOR at 0x230f4095a90>,
#   <__main__.FEAVECTOR at 0x230f4095af0>,
#   <__main__.FEAVECTOR at 0x230f4095bb0>,
#   <__main__.FEAVECTOR at 0x230f4095b50>,
#   <__main__.FEAVECTOR at 0x230f4095c10>,
#   <__main__.FEAVECTOR at 0x230f4095cd0>,
#   <__main__.FEAVECTOR at 0x230f4095d30>,
#   <__main__.FEAVECTOR at 0x230f4095d90>,
#   <__main__.FEAVECTOR at 0x230f4095df0>,
#   <__main__.FEAVECTOR at 0x230f4095c70>,
#   <__main__.FEAVECTOR at 0x230f4095e50>,
#   <__main__.FEAVECTOR at 0x230f4095f10>,
#   <__main__.FEAVECTOR at 0x230f4095f70>,
#   <__main__.FEAVECTOR at 0x230f4095fd0>,
#   <__main__.FEAVECTOR at 0x230f40a1070>,
#   <__main__.FEAVECTOR at 0x230f40a1040>,
#   <__main__.FEAVECTOR at 0x230f40a10d0>,
#   <__main__.FEAVECTOR at 0x230f40a1130>,
#   <__main__.FEAVECTOR at 0x230f40a1190>,
#   <__main__.FEAVECTOR at 0x230f40a1250>,
#   <__main__.FEAVECTOR at 0x230f40a11f0>,
#   <__main__.FEAVECTOR at 0x230f40a1310>,
#   <__main__.FEAVECTOR at 0x230f40a1370>,
#   <__main__.FEAVECTOR at 0x230f40a12b0>,
#   <__main__.FEAVECTOR at 0x230f40a13d0>,
#   <__main__.FEAVECTOR at 0x230f40a1430>,
#   <__main__.FEAVECTOR at 0x230f40a1490>,
#   <__main__.FEAVECTOR at 0x230f40a1550>,
#   <__main__.FEAVECTOR at 0x230f40a15b0>,
#   <__main__.FEAVECTOR at 0x230f40a1610>,
#   <__main__.FEAVECTOR at 0x230f40a1670>,
#   <__main__.FEAVECTOR at 0x230f40a16d0>,
#   <__main__.FEAVECTOR at 0x230f40a1730>,
#   <__main__.FEAVECTOR at 0x230f40a1790>,
#   <__main__.FEAVECTOR at 0x230f40a14f0>,
#   <__main__.FEAVECTOR at 0x230f40a17f0>,
#   <__main__.FEAVECTOR at 0x230f40a18b0>,
#   <__main__.FEAVECTOR at 0x230f40a1910>,
#   <__main__.FEAVECTOR at 0x230f40a1970>,
#   <__main__.FEAVECTOR at 0x230f40a19d0>,
#   <__main__.FEAVECTOR at 0x230f40a1850>,
#   <__main__.FEAVECTOR at 0x230f40a1a90>,
#   <__main__.FEAVECTOR at 0x230f40a1af0>,
#   <__main__.FEAVECTOR at 0x230f40a1a30>,
#   <__main__.FEAVECTOR at 0x230f40a1b50>,
#   <__main__.FEAVECTOR at 0x230f40a1c10>,
#   <__main__.FEAVECTOR at 0x230f40a1c70>,
#   <__main__.FEAVECTOR at 0x230f40a1bb0>,
#   <__main__.FEAVECTOR at 0x230f40a1cd0>],
#  [<__main__.FEAVECTOR at 0x230f40a1d90>,
#   <__main__.FEAVECTOR at 0x230f40a1d30>,
#   <__main__.FEAVECTOR at 0x230f40a1e50>,
#   <__main__.FEAVECTOR at 0x230f40a1eb0>,
#   <__main__.FEAVECTOR at 0x230f40a1df0>,
#   <__main__.FEAVECTOR at 0x230f40a1f70>,
#   <__main__.FEAVECTOR at 0x230f40a1f10>,
#   <__main__.FEAVECTOR at 0x230f40ad070>,
#   <__main__.FEAVECTOR at 0x230f40ad040>,
#   <__main__.FEAVECTOR at 0x230f40ad130>,
#   <__main__.FEAVECTOR at 0x230f40ad190>,
#   <__main__.FEAVECTOR at 0x230f40ad0d0>,
#   <__main__.FEAVECTOR at 0x230f40ad1f0>,
#   <__main__.FEAVECTOR at 0x230f40ad250>,
#   <__main__.FEAVECTOR at 0x230f40ad310>,
#   <__main__.FEAVECTOR at 0x230f40ad370>,
#   <__main__.FEAVECTOR at 0x230f40ad2b0>,
#   <__main__.FEAVECTOR at 0x230f40ad430>,
#   <__main__.FEAVECTOR at 0x230f40ad3d0>,
#   <__main__.FEAVECTOR at 0x230f40ad4f0>,
#   <__main__.FEAVECTOR at 0x230f40ad550>,
#   <__main__.FEAVECTOR at 0x230f40ad490>,
#   <__main__.FEAVECTOR at 0x230f40ad610>,
#   <__main__.FEAVECTOR at 0x230f40ad670>,
#   <__main__.FEAVECTOR at 0x230f40ad6d0>,
#   <__main__.FEAVECTOR at 0x230f40ad5b0>,
#   <__main__.FEAVECTOR at 0x230f40ad790>,
#   <__main__.FEAVECTOR at 0x230f40ad730>,
#   <__main__.FEAVECTOR at 0x230f40ad7f0>,
#   <__main__.FEAVECTOR at 0x230f40ad850>,
#   <__main__.FEAVECTOR at 0x230f40ad8b0>,
#   <__main__.FEAVECTOR at 0x230f40ad910>,
#   <__main__.FEAVECTOR at 0x230f40ad9d0>,
#   <__main__.FEAVECTOR at 0x230f40ad970>,
#   <__main__.FEAVECTOR at 0x230f40ada90>,
#   <__main__.FEAVECTOR at 0x230f40adaf0>,
#   <__main__.FEAVECTOR at 0x230f40ada30>,
#   <__main__.FEAVECTOR at 0x230f40adbb0>,
#   <__main__.FEAVECTOR at 0x230f40adb50>,
#   <__main__.FEAVECTOR at 0x230f40adc70>,
#   <__main__.FEAVECTOR at 0x230f40adc10>,
#   <__main__.FEAVECTOR at 0x230f40adcd0>,
#   <__main__.FEAVECTOR at 0x230f40add30>,
#   <__main__.FEAVECTOR at 0x230f40add90>,
#   <__main__.FEAVECTOR at 0x230f40addf0>,
#   <__main__.FEAVECTOR at 0x230f40adeb0>,
#   <__main__.FEAVECTOR at 0x230f40adf10>,
#   <__main__.FEAVECTOR at 0x230f40adf70>,
#   <__main__.FEAVECTOR at 0x230f40ade50>,
#   <__main__.FEAVECTOR at 0x230f40b9040>,
#   <__main__.FEAVECTOR at 0x230f40b90d0>,
#   <__main__.FEAVECTOR at 0x230f40b9070>,
#   <__main__.FEAVECTOR at 0x230f40b9190>,
#   <__main__.FEAVECTOR at 0x230f40b91f0>,
#   <__main__.FEAVECTOR at 0x230f40b9130>,
#   <__main__.FEAVECTOR at 0x230f40b92b0>,
#   <__main__.FEAVECTOR at 0x230f40b9310>,
#   <__main__.FEAVECTOR at 0x230f40b9370>,
#   <__main__.FEAVECTOR at 0x230f40b9250>,
#   <__main__.FEAVECTOR at 0x230f40b93d0>,
#   <__main__.FEAVECTOR at 0x230f40b9490>,
#   <__main__.FEAVECTOR at 0x230f40b94f0>,
#   <__main__.FEAVECTOR at 0x230f40b9430>,
#   <__main__.FEAVECTOR at 0x230f40b95b0>,
#   <__main__.FEAVECTOR at 0x230f40b9610>,
#   <__main__.FEAVECTOR at 0x230f40b9550>,
#   <__main__.FEAVECTOR at 0x230f40b9670>,
#   <__main__.FEAVECTOR at 0x230f40b96d0>,
#   <__main__.FEAVECTOR at 0x230f40b9730>,
#   <__main__.FEAVECTOR at 0x230f40b9790>,
#   <__main__.FEAVECTOR at 0x230f40b97f0>,
#   <__main__.FEAVECTOR at 0x230f40b98b0>,
#   <__main__.FEAVECTOR at 0x230f40b9910>,
#   <__main__.FEAVECTOR at 0x230f40b9970>,
#   <__main__.FEAVECTOR at 0x230f40b99d0>,
#   <__main__.FEAVECTOR at 0x230f40b9850>,
#   <__main__.FEAVECTOR at 0x230f40b9a30>,
#   <__main__.FEAVECTOR at 0x230f40b9a90>,
#   <__main__.FEAVECTOR at 0x230f40b9b50>,
#   <__main__.FEAVECTOR at 0x230f40b9af0>,
#   <__main__.FEAVECTOR at 0x230f40b9bb0>,
#   <__main__.FEAVECTOR at 0x230f40b9c70>,
#   <__main__.FEAVECTOR at 0x230f40b9cd0>,
#   <__main__.FEAVECTOR at 0x230f40b9d30>,
#   <__main__.FEAVECTOR at 0x230f40b9c10>,
#   <__main__.FEAVECTOR at 0x230f40b9df0>,
#   <__main__.FEAVECTOR at 0x230f40b9e50>,
#   <__main__.FEAVECTOR at 0x230f40b9d90>,
#   <__main__.FEAVECTOR at 0x230f40b9eb0>,
#   <__main__.FEAVECTOR at 0x230f40b9f10>,
#   <__main__.FEAVECTOR at 0x230f40b9fd0>,
#   <__main__.FEAVECTOR at 0x230f40c4070>,
#   <__main__.FEAVECTOR at 0x230f40c4040>,
#   <__main__.FEAVECTOR at 0x230f40c40d0>,
#   <__main__.FEAVECTOR at 0x230f40c4190>],
#  [<__main__.FEAVECTOR at 0x230f40c4130>,
#   <__main__.FEAVECTOR at 0x230f40c41f0>,
#   <__main__.FEAVECTOR at 0x230f40c42b0>,
#   <__main__.FEAVECTOR at 0x230f40c4310>,
#   <__main__.FEAVECTOR at 0x230f40c4250>,
#   <__main__.FEAVECTOR at 0x230f40c43d0>,
#   <__main__.FEAVECTOR at 0x230f40c4370>,
#   <__main__.FEAVECTOR at 0x230f40c4490>,
#   <__main__.FEAVECTOR at 0x230f40c44f0>,
#   <__main__.FEAVECTOR at 0x230f40c4550>,
#   <__main__.FEAVECTOR at 0x230f40c4430>,
#   <__main__.FEAVECTOR at 0x230f40c45b0>,
#   <__main__.FEAVECTOR at 0x230f40c4610>,
#   <__main__.FEAVECTOR at 0x230f40c46d0>,
#   <__main__.FEAVECTOR at 0x230f40c4730>,
#   <__main__.FEAVECTOR at 0x230f40c4790>,
#   <__main__.FEAVECTOR at 0x230f40c47f0>,
#   <__main__.FEAVECTOR at 0x230f40c4670>,
#   <__main__.FEAVECTOR at 0x230f40c48b0>,
#   <__main__.FEAVECTOR at 0x230f40c4850>,
#   <__main__.FEAVECTOR at 0x230f40c4970>,
#   <__main__.FEAVECTOR at 0x230f40c49d0>,
#   <__main__.FEAVECTOR at 0x230f40c4a30>,
#   <__main__.FEAVECTOR at 0x230f40c4a90>,
#   <__main__.FEAVECTOR at 0x230f40c4af0>,
#   <__main__.FEAVECTOR at 0x230f40c4b50>,
#   <__main__.FEAVECTOR at 0x230f40c4bb0>,
#   <__main__.FEAVECTOR at 0x230f40c4910>,
#   <__main__.FEAVECTOR at 0x230f40c4c10>,
#   <__main__.FEAVECTOR at 0x230f40c4c70>,
#   <__main__.FEAVECTOR at 0x230f40c4d30>,
#   <__main__.FEAVECTOR at 0x230f40c4d90>,
#   <__main__.FEAVECTOR at 0x230f40c4cd0>,
#   <__main__.FEAVECTOR at 0x230f40c4df0>,
#   <__main__.FEAVECTOR at 0x230f40c4eb0>,
#   <__main__.FEAVECTOR at 0x230f40c4e50>,
#   <__main__.FEAVECTOR at 0x230f40c4f70>,
#   <__main__.FEAVECTOR at 0x230f40c4f10>,
#   <__main__.FEAVECTOR at 0x230f40d0070>,
#   <__main__.FEAVECTOR at 0x230f40d0040>,
#   <__main__.FEAVECTOR at 0x230f40d00d0>,
#   <__main__.FEAVECTOR at 0x230f40d0190>,
#   <__main__.FEAVECTOR at 0x230f40d01f0>,
#   <__main__.FEAVECTOR at 0x230f40d0250>,
#   <__main__.FEAVECTOR at 0x230f40d0130>,
#   <__main__.FEAVECTOR at 0x230f40d0310>,
#   <__main__.FEAVECTOR at 0x230f40d0370>,
#   <__main__.FEAVECTOR at 0x230f40d03d0>,
#   <__main__.FEAVECTOR at 0x230f40d0430>,
#   <__main__.FEAVECTOR at 0x230f40d02b0>,
#   <__main__.FEAVECTOR at 0x230f40d0490>,
#   <__main__.FEAVECTOR at 0x230f40d04f0>,
#   <__main__.FEAVECTOR at 0x230f40d0550>,
#   <__main__.FEAVECTOR at 0x230f40d05b0>,
#   <__main__.FEAVECTOR at 0x230f40d0670>,
#   <__main__.FEAVECTOR at 0x230f40d0610>,
#   <__main__.FEAVECTOR at 0x230f40d06d0>,
#   <__main__.FEAVECTOR at 0x230f40d0790>,
#   <__main__.FEAVECTOR at 0x230f40d07f0>,
#   <__main__.FEAVECTOR at 0x230f40d0730>,
#   <__main__.FEAVECTOR at 0x230f40d08b0>,
#   <__main__.FEAVECTOR at 0x230f40d0850>,
#   <__main__.FEAVECTOR at 0x230f40d0970>,
#   <__main__.FEAVECTOR at 0x230f40d0910>,
#   <__main__.FEAVECTOR at 0x230f40d09d0>,
#   <__main__.FEAVECTOR at 0x230f40d0a30>,
#   <__main__.FEAVECTOR at 0x230f40d0af0>,
#   <__main__.FEAVECTOR at 0x230f40d0a90>,
#   <__main__.FEAVECTOR at 0x230f40d0bb0>,
#   <__main__.FEAVECTOR at 0x230f40d0b50>,
#   <__main__.FEAVECTOR at 0x230f40d0c10>,
#   <__main__.FEAVECTOR at 0x230f40d0c70>,
#   <__main__.FEAVECTOR at 0x230f40d0cd0>,
#   <__main__.FEAVECTOR at 0x230f40d0d30>,
#   <__main__.FEAVECTOR at 0x230f40d0d90>,
#   <__main__.FEAVECTOR at 0x230f40d0df0>,
#   <__main__.FEAVECTOR at 0x230f40d0eb0>,
#   <__main__.FEAVECTOR at 0x230f40d0e50>,
#   <__main__.FEAVECTOR at 0x230f40d0f70>,
#   <__main__.FEAVECTOR at 0x230f40d0f10>,
#   <__main__.FEAVECTOR at 0x230f40dc070>,
#   <__main__.FEAVECTOR at 0x230f40dc040>,
#   <__main__.FEAVECTOR at 0x230f40dc0d0>,
#   <__main__.FEAVECTOR at 0x230f40dc190>,
#   <__main__.FEAVECTOR at 0x230f40dc130>,
#   <__main__.FEAVECTOR at 0x230f40dc1f0>,
#   <__main__.FEAVECTOR at 0x230f40dc2b0>,
#   <__main__.FEAVECTOR at 0x230f40dc310>,
#   <__main__.FEAVECTOR at 0x230f40dc370>,
#   <__main__.FEAVECTOR at 0x230f40dc3d0>,
#   <__main__.FEAVECTOR at 0x230f40dc430>,
#   <__main__.FEAVECTOR at 0x230f40dc490>,
#   <__main__.FEAVECTOR at 0x230f40dc4f0>,
#   <__main__.FEAVECTOR at 0x230f40dc550>,
#   <__main__.FEAVECTOR at 0x230f40dc250>,
#   <__main__.FEAVECTOR at 0x230f40dc610>,
#   <__main__.FEAVECTOR at 0x230f40dc5b0>,
#   <__main__.FEAVECTOR at 0x230f40dc6d0>,
#   <__main__.FEAVECTOR at 0x230f40dc670>,
#   <__main__.FEAVECTOR at 0x230f40dc790>,
#   <__main__.FEAVECTOR at 0x230f40dc7f0>,
#   <__main__.FEAVECTOR at 0x230f40dc730>],
#  [<__main__.FEAVECTOR at 0x230f40dc8b0>,
#   <__main__.FEAVECTOR at 0x230f40dc910>,
#   <__main__.FEAVECTOR at 0x230f40dc850>,
#   <__main__.FEAVECTOR at 0x230f40dc970>,
#   <__main__.FEAVECTOR at 0x230f40dca30>,
#   <__main__.FEAVECTOR at 0x230f40dca90>,
#   <__main__.FEAVECTOR at 0x230f40dc9d0>,
#   <__main__.FEAVECTOR at 0x230f40dcaf0>,
#   <__main__.FEAVECTOR at 0x230f40dcb50>,
#   <__main__.FEAVECTOR at 0x230f40dcbb0>,
#   <__main__.FEAVECTOR at 0x230f40dcc70>,
#   <__main__.FEAVECTOR at 0x230f40dcc10>,
#   <__main__.FEAVECTOR at 0x230f40dcd30>,
#   <__main__.FEAVECTOR at 0x230f40dccd0>,
#   <__main__.FEAVECTOR at 0x230f40dcdf0>,
#   <__main__.FEAVECTOR at 0x230f40dce50>,
#   <__main__.FEAVECTOR at 0x230f40dceb0>,
#   <__main__.FEAVECTOR at 0x230f40dcf10>,
#   <__main__.FEAVECTOR at 0x230f40dcd90>,
#   <__main__.FEAVECTOR at 0x230f40dcf70>,
#   <__main__.FEAVECTOR at 0x230f40e8070>,
#   <__main__.FEAVECTOR at 0x230f40e80d0>,
#   <__main__.FEAVECTOR at 0x230f40e8130>,
#   <__main__.FEAVECTOR at 0x230f40e8190>,
#   <__main__.FEAVECTOR at 0x230f40e81f0>,
#   <__main__.FEAVECTOR at 0x230f40e8250>,
#   <__main__.FEAVECTOR at 0x230f40e8040>,
#   <__main__.FEAVECTOR at 0x230f40e82b0>,
#   <__main__.FEAVECTOR at 0x230f40e8310>,
#   <__main__.FEAVECTOR at 0x230f40e8370>,
#   <__main__.FEAVECTOR at 0x230f40e83d0>,
#   <__main__.FEAVECTOR at 0x230f40e8490>,
#   <__main__.FEAVECTOR at 0x230f40e84f0>,
#   <__main__.FEAVECTOR at 0x230f40e8430>,
#   <__main__.FEAVECTOR at 0x230f40e85b0>,
#   <__main__.FEAVECTOR at 0x230f40e8550>,
#   <__main__.FEAVECTOR at 0x230f40e8610>,
#   <__main__.FEAVECTOR at 0x230f40e86d0>,
#   <__main__.FEAVECTOR at 0x230f40e8670>,
#   <__main__.FEAVECTOR at 0x230f40e8790>,
#   <__main__.FEAVECTOR at 0x230f40e87f0>,
#   <__main__.FEAVECTOR at 0x230f40e8730>,
#   <__main__.FEAVECTOR at 0x230f40e88b0>,
#   <__main__.FEAVECTOR at 0x230f40e8910>,
#   <__main__.FEAVECTOR at 0x230f40e8970>,
#   <__main__.FEAVECTOR at 0x230f40e8850>,
#   <__main__.FEAVECTOR at 0x230f40e89d0>,
#   <__main__.FEAVECTOR at 0x230f40e8a30>,
#   <__main__.FEAVECTOR at 0x230f40e8af0>,
#   <__main__.FEAVECTOR at 0x230f40e8b50>,
#   <__main__.FEAVECTOR at 0x230f40e8a90>,
#   <__main__.FEAVECTOR at 0x230f40e8c10>,
#   <__main__.FEAVECTOR at 0x230f40e8bb0>,
#   <__main__.FEAVECTOR at 0x230f40e8cd0>,
#   <__main__.FEAVECTOR at 0x230f40e8c70>,
#   <__main__.FEAVECTOR at 0x230f40e8d90>,
#   <__main__.FEAVECTOR at 0x230f40e8d30>,
#   <__main__.FEAVECTOR at 0x230f40e8df0>,
#   <__main__.FEAVECTOR at 0x230f40e8eb0>,
#   <__main__.FEAVECTOR at 0x230f40e8e50>,
#   <__main__.FEAVECTOR at 0x230f40e8f70>,
#   <__main__.FEAVECTOR at 0x230f40e8fd0>,
#   <__main__.FEAVECTOR at 0x230f40f4070>,
#   <__main__.FEAVECTOR at 0x230f40f4040>,
#   <__main__.FEAVECTOR at 0x230f40f40d0>,
#   <__main__.FEAVECTOR at 0x230f40f4130>,
#   <__main__.FEAVECTOR at 0x230f40f4190>,
#   <__main__.FEAVECTOR at 0x230f40f41f0>,
#   <__main__.FEAVECTOR at 0x230f40f42b0>,
#   <__main__.FEAVECTOR at 0x230f40f4250>,
#   <__main__.FEAVECTOR at 0x230f40f4370>,
#   <__main__.FEAVECTOR at 0x230f40f43d0>,
#   <__main__.FEAVECTOR at 0x230f40f4430>,
#   <__main__.FEAVECTOR at 0x230f40f4490>,
#   <__main__.FEAVECTOR at 0x230f40f4310>,
#   <__main__.FEAVECTOR at 0x230f40f44f0>,
#   <__main__.FEAVECTOR at 0x230f40f4550>,
#   <__main__.FEAVECTOR at 0x230f40f4610>,
#   <__main__.FEAVECTOR at 0x230f40f4670>,
#   <__main__.FEAVECTOR at 0x230f40f46d0>,
#   <__main__.FEAVECTOR at 0x230f40f45b0>,
#   <__main__.FEAVECTOR at 0x230f40f4790>,
#   <__main__.FEAVECTOR at 0x230f40f4730>,
#   <__main__.FEAVECTOR at 0x230f40f47f0>,
#   <__main__.FEAVECTOR at 0x230f40f48b0>,
#   <__main__.FEAVECTOR at 0x230f40f4850>,
#   <__main__.FEAVECTOR at 0x230f40f4910>,
#   <__main__.FEAVECTOR at 0x230f40f49d0>,
#   <__main__.FEAVECTOR at 0x230f40f4970>,
#   <__main__.FEAVECTOR at 0x230f40f4a90>,
#   <__main__.FEAVECTOR at 0x230f40f4af0>,
#   <__main__.FEAVECTOR at 0x230f40f4b50>,
#   <__main__.FEAVECTOR at 0x230f40f4bb0>,
#   <__main__.FEAVECTOR at 0x230f40f4a30>,
#   <__main__.FEAVECTOR at 0x230f40f4c70>,
#   <__main__.FEAVECTOR at 0x230f40f4c10>,
#   <__main__.FEAVECTOR at 0x230f40f4d30>,
#   <__main__.FEAVECTOR at 0x230f40f4d90>,
#   <__main__.FEAVECTOR at 0x230f40f4df0>,
#   <__main__.FEAVECTOR at 0x230f40f4cd0>,
#   <__main__.FEAVECTOR at 0x230f40f4e50>],
#  [<__main__.FEAVECTOR at 0x230f40f4eb0>,
#   <__main__.FEAVECTOR at 0x230f40f4f70>,
#   <__main__.FEAVECTOR at 0x230f40f4f10>,
#   <__main__.FEAVECTOR at 0x230f4100040>,
#   <__main__.FEAVECTOR at 0x230f41000d0>,
#   <__main__.FEAVECTOR at 0x230f4100130>,
#   <__main__.FEAVECTOR at 0x230f4100190>,
#   <__main__.FEAVECTOR at 0x230f41001f0>,
#   <__main__.FEAVECTOR at 0x230f4100070>,
#   <__main__.FEAVECTOR at 0x230f4100250>,
#   <__main__.FEAVECTOR at 0x230f41002b0>,
#   <__main__.FEAVECTOR at 0x230f4100370>,
#   <__main__.FEAVECTOR at 0x230f4100310>,
#   <__main__.FEAVECTOR at 0x230f41003d0>,
#   <__main__.FEAVECTOR at 0x230f4100490>,
#   <__main__.FEAVECTOR at 0x230f41004f0>,
#   <__main__.FEAVECTOR at 0x230f4100550>,
#   <__main__.FEAVECTOR at 0x230f41005b0>,
#   <__main__.FEAVECTOR at 0x230f4100430>,
#   <__main__.FEAVECTOR at 0x230f4100610>,
#   <__main__.FEAVECTOR at 0x230f4100670>,
#   <__main__.FEAVECTOR at 0x230f4100730>,
#   <__main__.FEAVECTOR at 0x230f4100790>,
#   <__main__.FEAVECTOR at 0x230f41006d0>,
#   <__main__.FEAVECTOR at 0x230f41007f0>,
#   <__main__.FEAVECTOR at 0x230f41008b0>,
#   <__main__.FEAVECTOR at 0x230f4100850>,
#   <__main__.FEAVECTOR at 0x230f4100970>,
#   <__main__.FEAVECTOR at 0x230f4100910>,
#   <__main__.FEAVECTOR at 0x230f41009d0>,
#   <__main__.FEAVECTOR at 0x230f4100a90>,
#   <__main__.FEAVECTOR at 0x230f4100af0>,
#   <__main__.FEAVECTOR at 0x230f4100b50>,
#   <__main__.FEAVECTOR at 0x230f4100bb0>,
#   <__main__.FEAVECTOR at 0x230f4100a30>,
#   <__main__.FEAVECTOR at 0x230f4100c10>,
#   <__main__.FEAVECTOR at 0x230f4100c70>,
#   <__main__.FEAVECTOR at 0x230f4100cd0>,
#   <__main__.FEAVECTOR at 0x230f4100d90>,
#   <__main__.FEAVECTOR at 0x230f4100df0>,
#   <__main__.FEAVECTOR at 0x230f4100d30>,
#   <__main__.FEAVECTOR at 0x230f4100e50>,
#   <__main__.FEAVECTOR at 0x230f4100f10>,
#   <__main__.FEAVECTOR at 0x230f4100f70>,
#   <__main__.FEAVECTOR at 0x230f4100fd0>,
#   <__main__.FEAVECTOR at 0x230f410b070>,
#   <__main__.FEAVECTOR at 0x230f410b040>,
#   <__main__.FEAVECTOR at 0x230f410b0d0>,
#   <__main__.FEAVECTOR at 0x230f410b190>,
#   <__main__.FEAVECTOR at 0x230f410b1f0>,
#   <__main__.FEAVECTOR at 0x230f410b250>,
#   <__main__.FEAVECTOR at 0x230f410b2b0>,
#   <__main__.FEAVECTOR at 0x230f410b310>,
#   <__main__.FEAVECTOR at 0x230f410b370>,
#   <__main__.FEAVECTOR at 0x230f410b130>,
#   <__main__.FEAVECTOR at 0x230f410b430>,
#   <__main__.FEAVECTOR at 0x230f410b3d0>,
#   <__main__.FEAVECTOR at 0x230f410b4f0>,
#   <__main__.FEAVECTOR at 0x230f410b490>,
#   <__main__.FEAVECTOR at 0x230f410b550>,
#   <__main__.FEAVECTOR at 0x230f410b610>,
#   <__main__.FEAVECTOR at 0x230f410b5b0>,
#   <__main__.FEAVECTOR at 0x230f410b6d0>,
#   <__main__.FEAVECTOR at 0x230f410b730>,
#   <__main__.FEAVECTOR at 0x230f410b670>,
#   <__main__.FEAVECTOR at 0x230f410b790>,
#   <__main__.FEAVECTOR at 0x230f410b850>,
#   <__main__.FEAVECTOR at 0x230f410b7f0>,
#   <__main__.FEAVECTOR at 0x230f410b910>,
#   <__main__.FEAVECTOR at 0x230f410b8b0>,
#   <__main__.FEAVECTOR at 0x230f410b970>,
#   <__main__.FEAVECTOR at 0x230f410ba30>,
#   <__main__.FEAVECTOR at 0x230f410ba90>,
#   <__main__.FEAVECTOR at 0x230f410baf0>,
#   <__main__.FEAVECTOR at 0x230f410bb50>,
#   <__main__.FEAVECTOR at 0x230f410bbb0>,
#   <__main__.FEAVECTOR at 0x230f410bc10>,
#   <__main__.FEAVECTOR at 0x230f410b9d0>,
#   <__main__.FEAVECTOR at 0x230f410bc70>,
#   <__main__.FEAVECTOR at 0x230f410bd30>,
#   <__main__.FEAVECTOR at 0x230f410bd90>,
#   <__main__.FEAVECTOR at 0x230f410bdf0>,
#   <__main__.FEAVECTOR at 0x230f410be50>,
#   <__main__.FEAVECTOR at 0x230f410beb0>,
#   <__main__.FEAVECTOR at 0x230f410bf10>,
#   <__main__.FEAVECTOR at 0x230f410bcd0>,
#   <__main__.FEAVECTOR at 0x230f410bfd0>,
#   <__main__.FEAVECTOR at 0x230f4117070>,
#   <__main__.FEAVECTOR at 0x230f4117040>,
#   <__main__.FEAVECTOR at 0x230f4117130>,
#   <__main__.FEAVECTOR at 0x230f4117190>,
#   <__main__.FEAVECTOR at 0x230f41171f0>,
#   <__main__.FEAVECTOR at 0x230f41170d0>,
#   <__main__.FEAVECTOR at 0x230f4117250>,
#   <__main__.FEAVECTOR at 0x230f4117310>,
#   <__main__.FEAVECTOR at 0x230f4117370>,
#   <__main__.FEAVECTOR at 0x230f41173d0>,
#   <__main__.FEAVECTOR at 0x230f41172b0>,
#   <__main__.FEAVECTOR at 0x230f4117430>,
#   <__main__.FEAVECTOR at 0x230f4117490>,
#   <__main__.FEAVECTOR at 0x230f4117550>,
#   <__main__.FEAVECTOR at 0x230f41174f0>,
#   <__main__.FEAVECTOR at 0x230f41175b0>,
#   <__main__.FEAVECTOR at 0x230f4117670>,
#   <__main__.FEAVECTOR at 0x230f41176d0>,
#   <__main__.FEAVECTOR at 0x230f4117610>,
#   <__main__.FEAVECTOR at 0x230f4117730>],
#  [<__main__.FEAVECTOR at 0x230f4117790>,
#   <__main__.FEAVECTOR at 0x230f41177f0>,
#   <__main__.FEAVECTOR at 0x230f41178b0>,
#   <__main__.FEAVECTOR at 0x230f4117910>,
#   <__main__.FEAVECTOR at 0x230f4117850>,
#   <__main__.FEAVECTOR at 0x230f41179d0>,
#   <__main__.FEAVECTOR at 0x230f4117a30>,
#   <__main__.FEAVECTOR at 0x230f4117a90>,
#   <__main__.FEAVECTOR at 0x230f4117970>,
#   <__main__.FEAVECTOR at 0x230f4117b50>,
#   <__main__.FEAVECTOR at 0x230f4117af0>,
#   <__main__.FEAVECTOR at 0x230f4117bb0>,
#   <__main__.FEAVECTOR at 0x230f4117c70>,
#   <__main__.FEAVECTOR at 0x230f4117c10>,
#   <__main__.FEAVECTOR at 0x230f4117cd0>,
#   <__main__.FEAVECTOR at 0x230f4117d30>,
#   <__main__.FEAVECTOR at 0x230f4117d90>,
#   <__main__.FEAVECTOR at 0x230f4117df0>,
#   <__main__.FEAVECTOR at 0x230f4117eb0>,
#   <__main__.FEAVECTOR at 0x230f4117e50>,
#   <__main__.FEAVECTOR at 0x230f4117f70>,
#   <__main__.FEAVECTOR at 0x230f4117f10>,
#   <__main__.FEAVECTOR at 0x230f4163070>,
#   <__main__.FEAVECTOR at 0x230f4163040>,
#   <__main__.FEAVECTOR at 0x230f41630d0>,
#   <__main__.FEAVECTOR at 0x230f4163130>,
#   <__main__.FEAVECTOR at 0x230f4163190>,
#   <__main__.FEAVECTOR at 0x230f4163250>,
#   <__main__.FEAVECTOR at 0x230f41631f0>,
#   <__main__.FEAVECTOR at 0x230f4163310>,
#   <__main__.FEAVECTOR at 0x230f4163370>,
#   <__main__.FEAVECTOR at 0x230f41632b0>,
#   <__main__.FEAVECTOR at 0x230f4163430>,
#   <__main__.FEAVECTOR at 0x230f41633d0>,
#   <__main__.FEAVECTOR at 0x230f41634f0>,
#   <__main__.FEAVECTOR at 0x230f4163550>,
#   <__main__.FEAVECTOR at 0x230f41635b0>,
#   <__main__.FEAVECTOR at 0x230f4163490>,
#   <__main__.FEAVECTOR at 0x230f4163670>,
#   <__main__.FEAVECTOR at 0x230f41636d0>,
#   <__main__.FEAVECTOR at 0x230f4163610>,
#   <__main__.FEAVECTOR at 0x230f4163730>,
#   <__main__.FEAVECTOR at 0x230f41637f0>,
#   <__main__.FEAVECTOR at 0x230f4163850>,
#   <__main__.FEAVECTOR at 0x230f41638b0>,
#   <__main__.FEAVECTOR at 0x230f4163910>,
#   <__main__.FEAVECTOR at 0x230f4163970>,
#   <__main__.FEAVECTOR at 0x230f41639d0>,
#   <__main__.FEAVECTOR at 0x230f4163790>,
#   <__main__.FEAVECTOR at 0x230f4163a30>,
#   <__main__.FEAVECTOR at 0x230f4163af0>,
#   <__main__.FEAVECTOR at 0x230f4163b50>,
#   <__main__.FEAVECTOR at 0x230f4163bb0>,
#   <__main__.FEAVECTOR at 0x230f4163c10>,
#   <__main__.FEAVECTOR at 0x230f4163c70>,
#   <__main__.FEAVECTOR at 0x230f4163a90>,
#   <__main__.FEAVECTOR at 0x230f4163cd0>,
#   <__main__.FEAVECTOR at 0x230f4163d30>,
#   <__main__.FEAVECTOR at 0x230f4163d90>,
#   <__main__.FEAVECTOR at 0x230f4163df0>,
#   <__main__.FEAVECTOR at 0x230f4163e50>,
#   <__main__.FEAVECTOR at 0x230f4163f10>,
#   <__main__.FEAVECTOR at 0x230f4163f70>,
#   <__main__.FEAVECTOR at 0x230f4163fd0>,
#   <__main__.FEAVECTOR at 0x230f416f070>,
#   <__main__.FEAVECTOR at 0x230f416f040>,
#   <__main__.FEAVECTOR at 0x230f416f130>,
#   <__main__.FEAVECTOR at 0x230f416f190>,
#   <__main__.FEAVECTOR at 0x230f416f0d0>,
#   <__main__.FEAVECTOR at 0x230f416f1f0>,
#   <__main__.FEAVECTOR at 0x230f416f250>,
#   <__main__.FEAVECTOR at 0x230f416f310>,
#   <__main__.FEAVECTOR at 0x230f416f370>,
#   <__main__.FEAVECTOR at 0x230f416f3d0>,
#   <__main__.FEAVECTOR at 0x230f416f430>,
#   <__main__.FEAVECTOR at 0x230f416f490>,
#   <__main__.FEAVECTOR at 0x230f416f2b0>,
#   <__main__.FEAVECTOR at 0x230f416f4f0>,
#   <__main__.FEAVECTOR at 0x230f416f5b0>,
#   <__main__.FEAVECTOR at 0x230f416f550>,
#   <__main__.FEAVECTOR at 0x230f416f610>,
#   <__main__.FEAVECTOR at 0x230f416f6d0>,
#   <__main__.FEAVECTOR at 0x230f416f730>,
#   <__main__.FEAVECTOR at 0x230f416f670>,
#   <__main__.FEAVECTOR at 0x230f416f7f0>,
#   <__main__.FEAVECTOR at 0x230f416f850>,
#   <__main__.FEAVECTOR at 0x230f416f790>,
#   <__main__.FEAVECTOR at 0x230f416f8b0>,
#   <__main__.FEAVECTOR at 0x230f416f970>,
#   <__main__.FEAVECTOR at 0x230f416f9d0>,
#   <__main__.FEAVECTOR at 0x230f416f910>,
#   <__main__.FEAVECTOR at 0x230f416fa30>,
#   <__main__.FEAVECTOR at 0x230f416faf0>,
#   <__main__.FEAVECTOR at 0x230f416fa90>,
#   <__main__.FEAVECTOR at 0x230f416fb50>,
#   <__main__.FEAVECTOR at 0x230f416fbb0>,
#   <__main__.FEAVECTOR at 0x230f416fc70>,
#   <__main__.FEAVECTOR at 0x230f416fcd0>,
#   <__main__.FEAVECTOR at 0x230f416fc10>,
#   <__main__.FEAVECTOR at 0x230f416fd90>,
#   <__main__.FEAVECTOR at 0x230f416fdf0>,
#   <__main__.FEAVECTOR at 0x230f416fd30>,
#   <__main__.FEAVECTOR at 0x230f416fe50>,
#   <__main__.FEAVECTOR at 0x230f416ff10>,
#   <__main__.FEAVECTOR at 0x230f416ff70>,
#   <__main__.FEAVECTOR at 0x230f416feb0>,
#   <__main__.FEAVECTOR at 0x230f417b070>,
#   <__main__.FEAVECTOR at 0x230f417b040>,
#   <__main__.FEAVECTOR at 0x230f417b0d0>],
#  [<__main__.FEAVECTOR at 0x230f417b130>,
#   <__main__.FEAVECTOR at 0x230f417b1f0>,
#   <__main__.FEAVECTOR at 0x230f417b190>,
#   <__main__.FEAVECTOR at 0x230f417b250>,
#   <__main__.FEAVECTOR at 0x230f417b2b0>,
#   <__main__.FEAVECTOR at 0x230f417b370>,
#   <__main__.FEAVECTOR at 0x230f417b3d0>,
#   <__main__.FEAVECTOR at 0x230f417b310>,
#   <__main__.FEAVECTOR at 0x230f417b490>,
#   <__main__.FEAVECTOR at 0x230f417b430>,
#   <__main__.FEAVECTOR at 0x230f417b4f0>,
#   <__main__.FEAVECTOR at 0x230f417b5b0>,
#   <__main__.FEAVECTOR at 0x230f417b550>,
#   <__main__.FEAVECTOR at 0x230f417b610>,
#   <__main__.FEAVECTOR at 0x230f417b6d0>,
#   <__main__.FEAVECTOR at 0x230f417b670>,
#   <__main__.FEAVECTOR at 0x230f417b790>,
#   <__main__.FEAVECTOR at 0x230f417b730>,
#   <__main__.FEAVECTOR at 0x230f417b7f0>,
#   <__main__.FEAVECTOR at 0x230f417b8b0>,
#   <__main__.FEAVECTOR at 0x230f417b910>,
#   <__main__.FEAVECTOR at 0x230f417b850>,
#   <__main__.FEAVECTOR at 0x230f417b970>,
#   <__main__.FEAVECTOR at 0x230f417b9d0>,
#   <__main__.FEAVECTOR at 0x230f417ba90>,
#   <__main__.FEAVECTOR at 0x230f417baf0>,
#   <__main__.FEAVECTOR at 0x230f417bb50>,
#   <__main__.FEAVECTOR at 0x230f417bbb0>,
#   <__main__.FEAVECTOR at 0x230f417bc10>,
#   <__main__.FEAVECTOR at 0x230f417bc70>,
#   <__main__.FEAVECTOR at 0x230f417ba30>,
#   <__main__.FEAVECTOR at 0x230f417bd30>,
#   <__main__.FEAVECTOR at 0x230f417bd90>,
#   <__main__.FEAVECTOR at 0x230f417bdf0>,
#   <__main__.FEAVECTOR at 0x230f417be50>,
#   <__main__.FEAVECTOR at 0x230f417beb0>,
#   <__main__.FEAVECTOR at 0x230f417bcd0>,
#   <__main__.FEAVECTOR at 0x230f417bf10>,
#   <__main__.FEAVECTOR at 0x230f417bfd0>,
#   <__main__.FEAVECTOR at 0x230f4188040>,
#   <__main__.FEAVECTOR at 0x230f41880d0>,
#   <__main__.FEAVECTOR at 0x230f4188130>,
#   <__main__.FEAVECTOR at 0x230f4188190>,
#   <__main__.FEAVECTOR at 0x230f4188070>,
#   <__main__.FEAVECTOR at 0x230f41881f0>,
#   <__main__.FEAVECTOR at 0x230f41882b0>,
#   <__main__.FEAVECTOR at 0x230f4188310>,
#   <__main__.FEAVECTOR at 0x230f4188370>,
#   <__main__.FEAVECTOR at 0x230f41883d0>,
#   <__main__.FEAVECTOR at 0x230f4188430>,
#   <__main__.FEAVECTOR at 0x230f4188250>,
#   <__main__.FEAVECTOR at 0x230f4188490>,
#   <__main__.FEAVECTOR at 0x230f41884f0>,
#   <__main__.FEAVECTOR at 0x230f41885b0>,
#   <__main__.FEAVECTOR at 0x230f4188610>,
#   <__main__.FEAVECTOR at 0x230f4188670>,
#   <__main__.FEAVECTOR at 0x230f41886d0>,
#   <__main__.FEAVECTOR at 0x230f4188730>,
#   <__main__.FEAVECTOR at 0x230f4188550>,
#   <__main__.FEAVECTOR at 0x230f4188790>,
#   <__main__.FEAVECTOR at 0x230f4188850>,
#   <__main__.FEAVECTOR at 0x230f41888b0>,
#   <__main__.FEAVECTOR at 0x230f41887f0>,
#   <__main__.FEAVECTOR at 0x230f4188910>,
#   <__main__.FEAVECTOR at 0x230f41889d0>,
#   <__main__.FEAVECTOR at 0x230f4188a30>,
#   <__main__.FEAVECTOR at 0x230f4188a90>,
#   <__main__.FEAVECTOR at 0x230f4188af0>,
#   <__main__.FEAVECTOR at 0x230f4188970>,
#   <__main__.FEAVECTOR at 0x230f4188bb0>,
#   <__main__.FEAVECTOR at 0x230f4188b50>,
#   <__main__.FEAVECTOR at 0x230f4188c70>,
#   <__main__.FEAVECTOR at 0x230f4188c10>,
#   <__main__.FEAVECTOR at 0x230f4188d30>,
#   <__main__.FEAVECTOR at 0x230f4188d90>,
#   <__main__.FEAVECTOR at 0x230f4188cd0>,
#   <__main__.FEAVECTOR at 0x230f4188df0>,
#   <__main__.FEAVECTOR at 0x230f4188eb0>,
#   <__main__.FEAVECTOR at 0x230f4188f10>,
#   <__main__.FEAVECTOR at 0x230f4188f70>,
#   <__main__.FEAVECTOR at 0x230f4188e50>,
#   <__main__.FEAVECTOR at 0x230f4192040>,
#   <__main__.FEAVECTOR at 0x230f41920d0>,
#   <__main__.FEAVECTOR at 0x230f4192070>,
#   <__main__.FEAVECTOR at 0x230f4192130>,
#   <__main__.FEAVECTOR at 0x230f4192190>,
#   <__main__.FEAVECTOR at 0x230f4192250>,
#   <__main__.FEAVECTOR at 0x230f41922b0>,
#   <__main__.FEAVECTOR at 0x230f41921f0>,
#   <__main__.FEAVECTOR at 0x230f4192340>,
#   <__main__.FEAVECTOR at 0x230f4192310>,
#   <__main__.FEAVECTOR at 0x230f4192370>,
#   <__main__.FEAVECTOR at 0x230f41923d0>,
#   <__main__.FEAVECTOR at 0x230f41923a0>,
#   <__main__.FEAVECTOR at 0x230f4192430>,
#   <__main__.FEAVECTOR at 0x230f4192400>,
#   <__main__.FEAVECTOR at 0x230f4192490>,
#   <__main__.FEAVECTOR at 0x230f41924c0>,
#   <__main__.FEAVECTOR at 0x230f4192460>,
#   <__main__.FEAVECTOR at 0x230f41924f0>,
#   <__main__.FEAVECTOR at 0x230f4192520>,
#   <__main__.FEAVECTOR at 0x230f4192580>,
#   <__main__.FEAVECTOR at 0x230f4192550>,
#   <__main__.FEAVECTOR at 0x230f41925e0>,
#   <__main__.FEAVECTOR at 0x230f4192610>,
#   <__main__.FEAVECTOR at 0x230f41925b0>,
#   <__main__.FEAVECTOR at 0x230f4192640>,
#   <__main__.FEAVECTOR at 0x230f41926a0>,
#   <__main__.FEAVECTOR at 0x230f4192670>,
#   <__main__.FEAVECTOR at 0x230f4192700>],
#  [<__main__.FEAVECTOR at 0x230f4192730>,
#   <__main__.FEAVECTOR at 0x230f4192760>,
#   <__main__.FEAVECTOR at 0x230f41926d0>,
#   <__main__.FEAVECTOR at 0x230f41927c0>,
#   <__main__.FEAVECTOR at 0x230f41927f0>,
#   <__main__.FEAVECTOR at 0x230f4192820>,
#   <__main__.FEAVECTOR at 0x230f4192790>,
#   <__main__.FEAVECTOR at 0x230f4192850>,
#   <__main__.FEAVECTOR at 0x230f4192880>,
#   <__main__.FEAVECTOR at 0x230f41928e0>,
#   <__main__.FEAVECTOR at 0x230f4192910>,
#   <__main__.FEAVECTOR at 0x230f4192940>,
#   <__main__.FEAVECTOR at 0x230f4192970>,
#   <__main__.FEAVECTOR at 0x230f41928b0>,
#   <__main__.FEAVECTOR at 0x230f41929d0>,
#   <__main__.FEAVECTOR at 0x230f4192a00>,
#   <__main__.FEAVECTOR at 0x230f4192a30>,
#   <__main__.FEAVECTOR at 0x230f41929a0>,
#   <__main__.FEAVECTOR at 0x230f4192a90>,
#   <__main__.FEAVECTOR at 0x230f4192a60>,
#   <__main__.FEAVECTOR at 0x230f4192af0>,
#   <__main__.FEAVECTOR at 0x230f4192b20>,
#   <__main__.FEAVECTOR at 0x230f4192ac0>,
#   <__main__.FEAVECTOR at 0x230f4192b50>,
#   <__main__.FEAVECTOR at 0x230f4192b80>,
#   <__main__.FEAVECTOR at 0x230f4192bb0>,
#   <__main__.FEAVECTOR at 0x230f4192be0>,
#   <__main__.FEAVECTOR at 0x230f4192c40>,
#   <__main__.FEAVECTOR at 0x230f4192c10>,
#   <__main__.FEAVECTOR at 0x230f4192ca0>,
#   <__main__.FEAVECTOR at 0x230f4192cd0>,
#   <__main__.FEAVECTOR at 0x230f4192d00>,
#   <__main__.FEAVECTOR at 0x230f4192c70>,
#   <__main__.FEAVECTOR at 0x230f4192d30>,
#   <__main__.FEAVECTOR at 0x230f4192d90>,
#   <__main__.FEAVECTOR at 0x230f4192d60>,
#   <__main__.FEAVECTOR at 0x230f4192dc0>,
#   <__main__.FEAVECTOR at 0x230f4192df0>,
#   <__main__.FEAVECTOR at 0x230f4192e50>,
#   <__main__.FEAVECTOR at 0x230f4192e20>,
#   <__main__.FEAVECTOR at 0x230f4192eb0>,
#   <__main__.FEAVECTOR at 0x230f4192e80>,
#   <__main__.FEAVECTOR at 0x230f4192ee0>,
#   <__main__.FEAVECTOR at 0x230f4192f40>,
#   <__main__.FEAVECTOR at 0x230f4192f10>,
#   <__main__.FEAVECTOR at 0x230f4192fa0>,
#   <__main__.FEAVECTOR at 0x230f4192f70>,
#   <__main__.FEAVECTOR at 0x230f4192fd0>,
#   <__main__.FEAVECTOR at 0x230f41a8040>,
#   <__main__.FEAVECTOR at 0x230f41a80a0>,
#   <__main__.FEAVECTOR at 0x230f41a8070>,
#   <__main__.FEAVECTOR at 0x230f41a80d0>,
#   <__main__.FEAVECTOR at 0x230f41a8100>,
#   <__main__.FEAVECTOR at 0x230f41a8160>,
#   <__main__.FEAVECTOR at 0x230f41a8130>,
#   <__main__.FEAVECTOR at 0x230f41a8190>,
#   <__main__.FEAVECTOR at 0x230f41a81c0>,
#   <__main__.FEAVECTOR at 0x230f41a8220>,
#   <__main__.FEAVECTOR at 0x230f41a81f0>,
#   <__main__.FEAVECTOR at 0x230f41a8250>,
#   <__main__.FEAVECTOR at 0x230f41a82b0>,
#   <__main__.FEAVECTOR at 0x230f41a8280>,
#   <__main__.FEAVECTOR at 0x230f41a82e0>,
#   <__main__.FEAVECTOR at 0x230f41a8340>,
#   <__main__.FEAVECTOR at 0x230f41a8310>,
#   <__main__.FEAVECTOR at 0x230f41a83a0>,
#   <__main__.FEAVECTOR at 0x230f41a8370>,
#   <__main__.FEAVECTOR at 0x230f41a8400>,
#   <__main__.FEAVECTOR at 0x230f41a83d0>,
#   <__main__.FEAVECTOR at 0x230f41a8430>,
#   <__main__.FEAVECTOR at 0x230f41a8460>,
#   <__main__.FEAVECTOR at 0x230f41a8490>,
#   <__main__.FEAVECTOR at 0x230f41a84c0>,
#   <__main__.FEAVECTOR at 0x230f41a84f0>,
#   <__main__.FEAVECTOR at 0x230f41a8550>,
#   <__main__.FEAVECTOR at 0x230f41a8580>,
#   <__main__.FEAVECTOR at 0x230f41a8520>,
#   <__main__.FEAVECTOR at 0x230f41a85e0>,
#   <__main__.FEAVECTOR at 0x230f41a8610>,
#   <__main__.FEAVECTOR at 0x230f41a8640>,
#   <__main__.FEAVECTOR at 0x230f41a8670>,
#   <__main__.FEAVECTOR at 0x230f41a86a0>,
#   <__main__.FEAVECTOR at 0x230f41a86d0>,
#   <__main__.FEAVECTOR at 0x230f41a8700>,
#   <__main__.FEAVECTOR at 0x230f41a85b0>,
#   <__main__.FEAVECTOR at 0x230f41a8730>,
#   <__main__.FEAVECTOR at 0x230f41a8760>,
#   <__main__.FEAVECTOR at 0x230f41a8790>,
#   <__main__.FEAVECTOR at 0x230f41a87f0>,
#   <__main__.FEAVECTOR at 0x230f41a87c0>,
#   <__main__.FEAVECTOR at 0x230f41a8820>,
#   <__main__.FEAVECTOR at 0x230f41a8880>,
#   <__main__.FEAVECTOR at 0x230f41a88b0>,
#   <__main__.FEAVECTOR at 0x230f41a88e0>,
#   <__main__.FEAVECTOR at 0x230f41a8850>,
#   <__main__.FEAVECTOR at 0x230f41a8940>,
#   <__main__.FEAVECTOR at 0x230f41a8910>,
#   <__main__.FEAVECTOR at 0x230f41a8970>,
#   <__main__.FEAVECTOR at 0x230f41a89d0>,
#   <__main__.FEAVECTOR at 0x230f41a89a0>,
#   <__main__.FEAVECTOR at 0x230f41a8a00>,
#   <__main__.FEAVECTOR at 0x230f41a8a60>,
#   <__main__.FEAVECTOR at 0x230f41a8a30>,
#   <__main__.FEAVECTOR at 0x230f41a8ac0>,
#   <__main__.FEAVECTOR at 0x230f41a8af0>,
#   <__main__.FEAVECTOR at 0x230f41a8b20>,
#   <__main__.FEAVECTOR at 0x230f41a8b50>,
#   <__main__.FEAVECTOR at 0x230f41a8a90>,
#   <__main__.FEAVECTOR at 0x230f41a8b80>,
#   <__main__.FEAVECTOR at 0x230f41a8bb0>,
#   <__main__.FEAVECTOR at 0x230f41a8be0>],
#  [<__main__.FEAVECTOR at 0x230f41a8c10>,
#   <__main__.FEAVECTOR at 0x230f41a8c40>,
#   <__main__.FEAVECTOR at 0x230f41a8c70>,
#   <__main__.FEAVECTOR at 0x230f41a8cd0>,
#   <__main__.FEAVECTOR at 0x230f41a8d00>,
#   <__main__.FEAVECTOR at 0x230f41a8d30>,
# ...
#   <__main__.FEAVECTOR at 0x230f4072760>,
#   <__main__.FEAVECTOR at 0x230f4072820>,
#   <__main__.FEAVECTOR at 0x230f40728e0>,
#   <__main__.FEAVECTOR at 0x230f40725e0>,
#   <__main__.FEAVECTOR at 0x230f40729a0>,
#   <__main__.FEAVECTOR at 0x230f4072a60>,
#   <__main__.FEAVECTOR at 0x230f4072be0>,
#   <__main__.FEAVECTOR at 0x230f4072ca0>,
#   <__main__.FEAVECTOR at 0x230f4072b20>,
#   <__main__.FEAVECTOR at 0x230f4072e20>,
#   <__main__.FEAVECTOR at 0x230f4072d60>,
#   <__main__.FEAVECTOR at 0x230f4072fa0>,
#   <__main__.FEAVECTOR at 0x230f4072ee0>,
#   <__main__.FEAVECTOR at 0x230f407d160>,
#   <__main__.FEAVECTOR at 0x230f407d0a0>,
#   <__main__.FEAVECTOR at 0x230f407d220>,
#   <__main__.FEAVECTOR at 0x230f407d3a0>,
#   <__main__.FEAVECTOR at 0x230f407d2e0>,
#   <__main__.FEAVECTOR at 0x230f407d520>,
#   <__main__.FEAVECTOR at 0x230f407d460>,
#   <__main__.FEAVECTOR at 0x230f407d5e0>,
#   <__main__.FEAVECTOR at 0x230f407d760>,
#   <__main__.FEAVECTOR at 0x230f407d820>,
#   <__main__.FEAVECTOR at 0x230f407d8e0>,
#   <__main__.FEAVECTOR at 0x230f407d9a0>,
#   <__main__.FEAVECTOR at 0x230f407da60>,
#   <__main__.FEAVECTOR at 0x230f407d6a0>,
#   <__main__.FEAVECTOR at 0x230f407db20>,
#   <__main__.FEAVECTOR at 0x230f407dca0>,
#   <__main__.FEAVECTOR at 0x230f407dd60>,
#   <__main__.FEAVECTOR at 0x230f407de20>,
#   <__main__.FEAVECTOR at 0x230f407dbe0>,
#   <__main__.FEAVECTOR at 0x230f407dee0>,
#   <__main__.FEAVECTOR at 0x230f407dfa0>,
#   <__main__.FEAVECTOR at 0x230f4089160>,
#   <__main__.FEAVECTOR at 0x230f4089220>,
#   <__main__.FEAVECTOR at 0x230f40890a0>,
#   <__main__.FEAVECTOR at 0x230f40892e0>,
#   <__main__.FEAVECTOR at 0x230f4089460>,
#   <__main__.FEAVECTOR at 0x230f40893a0>,
#   <__main__.FEAVECTOR at 0x230f40895e0>,
#   <__main__.FEAVECTOR at 0x230f40896a0>,
#   <__main__.FEAVECTOR at 0x230f4089520>,
#   <__main__.FEAVECTOR at 0x230f4089820>,
#   <__main__.FEAVECTOR at 0x230f40898e0>,
#   <__main__.FEAVECTOR at 0x230f4089760>,
#   <__main__.FEAVECTOR at 0x230f40899a0>,
#   <__main__.FEAVECTOR at 0x230f4089b20>,
#   <__main__.FEAVECTOR at 0x230f4089a60>,
#   <__main__.FEAVECTOR at 0x230f4089be0>,
#   <__main__.FEAVECTOR at 0x230f4089ca0>,
#   <__main__.FEAVECTOR at 0x230f4089d60>,
#   <__main__.FEAVECTOR at 0x230f4089e20>,
#   <__main__.FEAVECTOR at 0x230f4089ee0>,
#   <__main__.FEAVECTOR at 0x230f4089fa0>,
#   <__main__.FEAVECTOR at 0x230f40950a0>,
#   <__main__.FEAVECTOR at 0x230f4095220>,
#   <__main__.FEAVECTOR at 0x230f4095160>,
#   <__main__.FEAVECTOR at 0x230f40953a0>,
#   <__main__.FEAVECTOR at 0x230f4095460>,
#   <__main__.FEAVECTOR at 0x230f40952e0>,
#   <__main__.FEAVECTOR at 0x230f40955e0>,
#   <__main__.FEAVECTOR at 0x230f40956a0>,
#   <__main__.FEAVECTOR at 0x230f4095760>,
#   <__main__.FEAVECTOR at 0x230f4095820>,
#   <__main__.FEAVECTOR at 0x230f40958e0>,
#   <__main__.FEAVECTOR at 0x230f40959a0>,
#   <__main__.FEAVECTOR at 0x230f4095a60>,
#   <__main__.FEAVECTOR at 0x230f4095520>,
#   <__main__.FEAVECTOR at 0x230f4095b20>,
#   <__main__.FEAVECTOR at 0x230f4095ca0>,
#   <__main__.FEAVECTOR at 0x230f4095d60>,
#   <__main__.FEAVECTOR at 0x230f4095be0>,
#   <__main__.FEAVECTOR at 0x230f4095ee0>,
#   <__main__.FEAVECTOR at 0x230f4095fa0>,
#   <__main__.FEAVECTOR at 0x230f4095e20>,
#   <__main__.FEAVECTOR at 0x230f40a10a0>,
#   <__main__.FEAVECTOR at 0x230f40a1160>,
#   <__main__.FEAVECTOR at 0x230f40a1220>,
#   <__main__.FEAVECTOR at 0x230f40a13a0>,
#   <__main__.FEAVECTOR at 0x230f40a12e0>,
#   <__main__.FEAVECTOR at 0x230f40a1520>,
#   <__main__.FEAVECTOR at 0x230f40a1460>,
#   <__main__.FEAVECTOR at 0x230f40a16a0>,
#   <__main__.FEAVECTOR at 0x230f40a1760>,
#   <__main__.FEAVECTOR at 0x230f40a15e0>,
#   <__main__.FEAVECTOR at 0x230f40a1820>,
#   <__main__.FEAVECTOR at 0x230f40a18e0>,
#   <__main__.FEAVECTOR at 0x230f40a19a0>,
#   <__main__.FEAVECTOR at 0x230f40a1a60>,
#   <__main__.FEAVECTOR at 0x230f40a1b20>,
#   <__main__.FEAVECTOR at 0x230f40a1be0>,
#   <__main__.FEAVECTOR at 0x230f40a1d60>,
#   <__main__.FEAVECTOR at 0x230f40a1ca0>,
#   <__main__.FEAVECTOR at 0x230f40a1ee0>,
#   <__main__.FEAVECTOR at 0x230f40a1fa0>,
#   <__main__.FEAVECTOR at 0x230f40a1e20>,
#   <__main__.FEAVECTOR at 0x230f40ad0a0>,
#   <__main__.FEAVECTOR at 0x230f40ad160>,
#   <__main__.FEAVECTOR at 0x230f40ad220>,
#   <__main__.FEAVECTOR at 0x230f40ad3a0>,
#   <__main__.FEAVECTOR at 0x230f40ad460>,
#   <__main__.FEAVECTOR at 0x230f40ad520>,
#   <__main__.FEAVECTOR at 0x230f40ad2e0>,
#   <__main__.FEAVECTOR at 0x230f40ad5e0>,
#   <__main__.FEAVECTOR at 0x230f40ad6a0>,
#   <__main__.FEAVECTOR at 0x230f40ad760>,
#   <__main__.FEAVECTOR at 0x230f40ad820>,
#   <__main__.FEAVECTOR at 0x230f40ad8e0>,
#   <__main__.FEAVECTOR at 0x230f40ad9a0>,
#   <__main__.FEAVECTOR at 0x230f40ada60>,
#   <__main__.FEAVECTOR at 0x230f40adbe0>,
#   <__main__.FEAVECTOR at 0x230f40adca0>,
#   <__main__.FEAVECTOR at 0x230f40adb20>,
#   <__main__.FEAVECTOR at 0x230f40ade20>,
#   <__main__.FEAVECTOR at 0x230f40add60>,
#   <__main__.FEAVECTOR at 0x230f40adee0>,
#   <__main__.FEAVECTOR at 0x230f40adfa0>,
#   <__main__.FEAVECTOR at 0x230f40b9160>,
#   <__main__.FEAVECTOR at 0x230f40b9220>,
#   <__main__.FEAVECTOR at 0x230f40b92e0>,
#   <__main__.FEAVECTOR at 0x230f40b90a0>,
#   <__main__.FEAVECTOR at 0x230f40b93a0>,
#   <__main__.FEAVECTOR at 0x230f40b9460>,
#   <__main__.FEAVECTOR at 0x230f40b9520>,
#   <__main__.FEAVECTOR at 0x230f40b95e0>,
#   <__main__.FEAVECTOR at 0x230f40b9760>,
#   <__main__.FEAVECTOR at 0x230f40b9820>,
#   <__main__.FEAVECTOR at 0x230f40b96a0>,
#   <__main__.FEAVECTOR at 0x230f40b98e0>,
#   <__main__.FEAVECTOR at 0x230f40b99a0>,
#   <__main__.FEAVECTOR at 0x230f40b9a60>,
#   <__main__.FEAVECTOR at 0x230f40b9be0>,
#   <__main__.FEAVECTOR at 0x230f40b9ca0>,
#   <__main__.FEAVECTOR at 0x230f40b9d60>,
#   <__main__.FEAVECTOR at 0x230f40b9e20>,
#   <__main__.FEAVECTOR at 0x230f40b9b20>,
#   <__main__.FEAVECTOR at 0x230f40b9ee0>,
#   <__main__.FEAVECTOR at 0x230f40b9fa0>,
#   <__main__.FEAVECTOR at 0x230f40c4160>,
#   <__main__.FEAVECTOR at 0x230f40c40a0>,
#   <__main__.FEAVECTOR at 0x230f40c4220>,
#   <__main__.FEAVECTOR at 0x230f40c43a0>,
#   <__main__.FEAVECTOR at 0x230f40c42e0>,
#   <__main__.FEAVECTOR at 0x230f40c4520>,
#   <__main__.FEAVECTOR at 0x230f40c4460>,
#   <__main__.FEAVECTOR at 0x230f40c46a0>,
#   <__main__.FEAVECTOR at 0x230f40c45e0>,
#   <__main__.FEAVECTOR at 0x230f40c4820>,
#   <__main__.FEAVECTOR at 0x230f40c48e0>,
#   <__main__.FEAVECTOR at 0x230f40c4760>,
#   <__main__.FEAVECTOR at 0x230f40c49a0>,
#   <__main__.FEAVECTOR at 0x230f40c4a60>,
#   <__main__.FEAVECTOR at 0x230f40c4be0>,
#   <__main__.FEAVECTOR at 0x230f40c4ca0>,
#   <__main__.FEAVECTOR at 0x230f40c4d60>,
#   <__main__.FEAVECTOR at 0x230f40c4b20>,
#   <__main__.FEAVECTOR at 0x230f40c4e20>],
#  [<__main__.FEAVECTOR at 0x230f40c4ee0>,
#   <__main__.FEAVECTOR at 0x230f40c4fa0>,
#   <__main__.FEAVECTOR at 0x230f40d00a0>,
#   <__main__.FEAVECTOR at 0x230f40d0160>,
#   <__main__.FEAVECTOR at 0x230f40d0220>,
#   <__main__.FEAVECTOR at 0x230f40d02e0>,
#   <__main__.FEAVECTOR at 0x230f40d0460>,
#   <__main__.FEAVECTOR at 0x230f40d03a0>,
#   <__main__.FEAVECTOR at 0x230f40d0520>,
#   <__main__.FEAVECTOR at 0x230f40d06a0>,
#   <__main__.FEAVECTOR at 0x230f40d05e0>,
#   <__main__.FEAVECTOR at 0x230f40d0760>,
#   <__main__.FEAVECTOR at 0x230f40d0820>,
#   <__main__.FEAVECTOR at 0x230f40d08e0>,
#   <__main__.FEAVECTOR at 0x230f40d0a60>,
#   <__main__.FEAVECTOR at 0x230f40d0b20>,
#   <__main__.FEAVECTOR at 0x230f40d09a0>,
#   <__main__.FEAVECTOR at 0x230f40d0be0>,
#   <__main__.FEAVECTOR at 0x230f40d0d60>,
#   <__main__.FEAVECTOR at 0x230f40d0ca0>,
#   <__main__.FEAVECTOR at 0x230f40d0ee0>,
#   <__main__.FEAVECTOR at 0x230f40d0e20>,
#   <__main__.FEAVECTOR at 0x230f40d0fa0>,
#   <__main__.FEAVECTOR at 0x230f40dc0a0>,
#   <__main__.FEAVECTOR at 0x230f40dc220>,
#   <__main__.FEAVECTOR at 0x230f40dc2e0>,
#   <__main__.FEAVECTOR at 0x230f40dc160>,
#   <__main__.FEAVECTOR at 0x230f40dc460>,
#   <__main__.FEAVECTOR at 0x230f40dc3a0>,
#   <__main__.FEAVECTOR at 0x230f40dc520>,
#   <__main__.FEAVECTOR at 0x230f40dc5e0>,
#   <__main__.FEAVECTOR at 0x230f40dc760>,
#   <__main__.FEAVECTOR at 0x230f40dc820>,
#   <__main__.FEAVECTOR at 0x230f40dc6a0>,
#   <__main__.FEAVECTOR at 0x230f40dc8e0>,
#   <__main__.FEAVECTOR at 0x230f40dca60>,
#   <__main__.FEAVECTOR at 0x230f40dcb20>,
#   <__main__.FEAVECTOR at 0x230f40dc9a0>,
#   <__main__.FEAVECTOR at 0x230f40dcca0>,
#   <__main__.FEAVECTOR at 0x230f40dcbe0>,
#   <__main__.FEAVECTOR at 0x230f40dce20>,
#   <__main__.FEAVECTOR at 0x230f40dcee0>,
#   <__main__.FEAVECTOR at 0x230f40dcd60>,
#   <__main__.FEAVECTOR at 0x230f40dcfa0>,
#   <__main__.FEAVECTOR at 0x230f40e80a0>,
#   <__main__.FEAVECTOR at 0x230f40e8220>,
#   <__main__.FEAVECTOR at 0x230f40e82e0>,
#   <__main__.FEAVECTOR at 0x230f40e8160>,
#   <__main__.FEAVECTOR at 0x230f40e8460>,
#   <__main__.FEAVECTOR at 0x230f40e83a0>,
#   <__main__.FEAVECTOR at 0x230f40e8520>,
#   <__main__.FEAVECTOR at 0x230f40e85e0>,
#   <__main__.FEAVECTOR at 0x230f40e8760>,
#   <__main__.FEAVECTOR at 0x230f40e8820>,
#   <__main__.FEAVECTOR at 0x230f40e86a0>,
#   <__main__.FEAVECTOR at 0x230f40e89a0>,
#   <__main__.FEAVECTOR at 0x230f40e8a60>,
#   <__main__.FEAVECTOR at 0x230f40e8b20>,
#   <__main__.FEAVECTOR at 0x230f40e8be0>,
#   <__main__.FEAVECTOR at 0x230f40e88e0>,
#   <__main__.FEAVECTOR at 0x230f40e8ca0>,
#   <__main__.FEAVECTOR at 0x230f40e8e20>,
#   <__main__.FEAVECTOR at 0x230f40e8ee0>,
#   <__main__.FEAVECTOR at 0x230f40e8fa0>,
#   <__main__.FEAVECTOR at 0x230f40e8d60>,
#   <__main__.FEAVECTOR at 0x230f40f4160>,
#   <__main__.FEAVECTOR at 0x230f40f4220>,
#   <__main__.FEAVECTOR at 0x230f40f40a0>,
#   <__main__.FEAVECTOR at 0x230f40f43a0>,
#   <__main__.FEAVECTOR at 0x230f40f4460>,
#   <__main__.FEAVECTOR at 0x230f40f4520>,
#   <__main__.FEAVECTOR at 0x230f40f45e0>,
#   <__main__.FEAVECTOR at 0x230f40f42e0>,
#   <__main__.FEAVECTOR at 0x230f40f4760>,
#   <__main__.FEAVECTOR at 0x230f40f4820>,
#   <__main__.FEAVECTOR at 0x230f40f46a0>,
#   <__main__.FEAVECTOR at 0x230f40f48e0>,
#   <__main__.FEAVECTOR at 0x230f40f4a60>,
#   <__main__.FEAVECTOR at 0x230f40f49a0>,
#   <__main__.FEAVECTOR at 0x230f40f4be0>,
#   <__main__.FEAVECTOR at 0x230f40f4b20>,
#   <__main__.FEAVECTOR at 0x230f40f4d60>,
#   <__main__.FEAVECTOR at 0x230f40f4ca0>,
#   <__main__.FEAVECTOR at 0x230f40f4ee0>,
#   <__main__.FEAVECTOR at 0x230f40f4fa0>,
#   <__main__.FEAVECTOR at 0x230f40f4e20>,
#   <__main__.FEAVECTOR at 0x230f4100160>,
#   <__main__.FEAVECTOR at 0x230f4100220>,
#   <__main__.FEAVECTOR at 0x230f41002e0>,
#   <__main__.FEAVECTOR at 0x230f41000a0>,
#   <__main__.FEAVECTOR at 0x230f41003a0>,
#   <__main__.FEAVECTOR at 0x230f4100460>,
#   <__main__.FEAVECTOR at 0x230f4100520>,
#   <__main__.FEAVECTOR at 0x230f41006a0>,
#   <__main__.FEAVECTOR at 0x230f4100760>,
#   <__main__.FEAVECTOR at 0x230f41005e0>,
#   <__main__.FEAVECTOR at 0x230f41008e0>,
#   <__main__.FEAVECTOR at 0x230f41009a0>,
#   <__main__.FEAVECTOR at 0x230f4100a60>,
#   <__main__.FEAVECTOR at 0x230f4100b20>,
#   <__main__.FEAVECTOR at 0x230f4100be0>,
#   <__main__.FEAVECTOR at 0x230f4100ca0>,
#   <__main__.FEAVECTOR at 0x230f4100d60>,
#   <__main__.FEAVECTOR at 0x230f4100e20>,
#   <__main__.FEAVECTOR at 0x230f4100ee0>,
#   <__main__.FEAVECTOR at 0x230f4100fa0>,
#   <__main__.FEAVECTOR at 0x230f4100820>,
#   <__main__.FEAVECTOR at 0x230f410b0a0>,
#   <__main__.FEAVECTOR at 0x230f410b220>,
#   <__main__.FEAVECTOR at 0x230f410b2e0>,
#   <__main__.FEAVECTOR at 0x230f410b3a0>,
#   <__main__.FEAVECTOR at 0x230f410b460>,
#   <__main__.FEAVECTOR at 0x230f410b160>,
#   <__main__.FEAVECTOR at 0x230f410b5e0>,
#   <__main__.FEAVECTOR at 0x230f410b520>,
#   <__main__.FEAVECTOR at 0x230f410b6a0>,
#   <__main__.FEAVECTOR at 0x230f410b760>,
#   <__main__.FEAVECTOR at 0x230f410b8e0>,
#   <__main__.FEAVECTOR at 0x230f410b9a0>,
#   <__main__.FEAVECTOR at 0x230f410ba60>,
#   <__main__.FEAVECTOR at 0x230f410b820>,
#   <__main__.FEAVECTOR at 0x230f410bb20>,
#   <__main__.FEAVECTOR at 0x230f410bbe0>,
#   <__main__.FEAVECTOR at 0x230f410bca0>,
#   <__main__.FEAVECTOR at 0x230f410be20>,
#   <__main__.FEAVECTOR at 0x230f410bd60>,
#   <__main__.FEAVECTOR at 0x230f410bee0>,
#   <__main__.FEAVECTOR at 0x230f410bfa0>,
#   <__main__.FEAVECTOR at 0x230f41170a0>,
#   <__main__.FEAVECTOR at 0x230f4117160>,
#   <__main__.FEAVECTOR at 0x230f41172e0>,
#   <__main__.FEAVECTOR at 0x230f41173a0>,
#   <__main__.FEAVECTOR at 0x230f4117220>,
#   <__main__.FEAVECTOR at 0x230f4117520>,
#   <__main__.FEAVECTOR at 0x230f4117460>,
#   <__main__.FEAVECTOR at 0x230f41176a0>,
#   <__main__.FEAVECTOR at 0x230f4117760>,
#   <__main__.FEAVECTOR at 0x230f4117820>,
#   <__main__.FEAVECTOR at 0x230f41178e0>,
#   <__main__.FEAVECTOR at 0x230f41179a0>,
#   <__main__.FEAVECTOR at 0x230f4117a60>,
#   <__main__.FEAVECTOR at 0x230f4117b20>,
#   <__main__.FEAVECTOR at 0x230f4117be0>,
#   <__main__.FEAVECTOR at 0x230f4117ca0>,
#   <__main__.FEAVECTOR at 0x230f4117d60>,
#   <__main__.FEAVECTOR at 0x230f41175e0>,
#   <__main__.FEAVECTOR at 0x230f4117ee0>,
#   <__main__.FEAVECTOR at 0x230f4117fa0>,
#   <__main__.FEAVECTOR at 0x230f4117e20>,
#   <__main__.FEAVECTOR at 0x230f41630a0>,
#   <__main__.FEAVECTOR at 0x230f4163220>,
#   <__main__.FEAVECTOR at 0x230f41632e0>,
#   <__main__.FEAVECTOR at 0x230f4163160>,
#   <__main__.FEAVECTOR at 0x230f41633a0>,
#   <__main__.FEAVECTOR at 0x230f4163460>,
#   <__main__.FEAVECTOR at 0x230f4163520>,
#   <__main__.FEAVECTOR at 0x230f41636a0>,
#   <__main__.FEAVECTOR at 0x230f4163760>,
#   <__main__.FEAVECTOR at 0x230f4163820>,
#   <__main__.FEAVECTOR at 0x230f41635e0>,
#   <__main__.FEAVECTOR at 0x230f41638e0>,
#   <__main__.FEAVECTOR at 0x230f41639a0>,
#   <__main__.FEAVECTOR at 0x230f4163a60>,
#   <__main__.FEAVECTOR at 0x230f4163b20>,
#   <__main__.FEAVECTOR at 0x230f4163ca0>,
#   <__main__.FEAVECTOR at 0x230f4163d60>,
#   <__main__.FEAVECTOR at 0x230f4163be0>,
#   <__main__.FEAVECTOR at 0x230f4163ee0>,
#   <__main__.FEAVECTOR at 0x230f4163fa0>,
#   <__main__.FEAVECTOR at 0x230f4163e20>,
#   <__main__.FEAVECTOR at 0x230f416f160>,
#   <__main__.FEAVECTOR at 0x230f416f0a0>,
#   <__main__.FEAVECTOR at 0x230f416f2e0>,
#   <__main__.FEAVECTOR at 0x230f416f220>,
#   <__main__.FEAVECTOR at 0x230f416f460>,
#   <__main__.FEAVECTOR at 0x230f416f3a0>,
#   <__main__.FEAVECTOR at 0x230f416f5e0>,
#   <__main__.FEAVECTOR at 0x230f416f6a0>,
#   <__main__.FEAVECTOR at 0x230f416f760>,
#   <__main__.FEAVECTOR at 0x230f416f520>,
#   <__main__.FEAVECTOR at 0x230f416f820>,
#   <__main__.FEAVECTOR at 0x230f416f8e0>,
#   <__main__.FEAVECTOR at 0x230f416f9a0>,
#   <__main__.FEAVECTOR at 0x230f416fb20>,
#   <__main__.FEAVECTOR at 0x230f416fa60>,
#   <__main__.FEAVECTOR at 0x230f416fbe0>,
#   <__main__.FEAVECTOR at 0x230f416fca0>,
#   <__main__.FEAVECTOR at 0x230f416fd60>,
#   <__main__.FEAVECTOR at 0x230f416fe20>,
#   <__main__.FEAVECTOR at 0x230f416ffa0>,
#   <__main__.FEAVECTOR at 0x230f416fee0>,
#   <__main__.FEAVECTOR at 0x230f417b0a0>,
#   <__main__.FEAVECTOR at 0x230f417b160>,
#   <__main__.FEAVECTOR at 0x230f417b220>,
#   <__main__.FEAVECTOR at 0x230f417b3a0>,
#   <__main__.FEAVECTOR at 0x230f417b2e0>,
#   <__main__.FEAVECTOR at 0x230f417b460>,
#   <__main__.FEAVECTOR at 0x230f417b520>,
#   <__main__.FEAVECTOR at 0x230f417b5e0>,
#   <__main__.FEAVECTOR at 0x230f417b6a0>,
#   <__main__.FEAVECTOR at 0x230f417b820>,
#   <__main__.FEAVECTOR at 0x230f417b8e0>,
#   <__main__.FEAVECTOR at 0x230f417b9a0>,
#   <__main__.FEAVECTOR at 0x230f417b760>,
#   <__main__.FEAVECTOR at 0x230f417ba60>,
#   <__main__.FEAVECTOR at 0x230f417bb20>,
#   <__main__.FEAVECTOR at 0x230f417bca0>,
#   <__main__.FEAVECTOR at 0x230f417bd60>,
#   <__main__.FEAVECTOR at 0x230f417be20>,
#   <__main__.FEAVECTOR at 0x230f417bee0>,
#   <__main__.FEAVECTOR at 0x230f417bbe0>,
#   <__main__.FEAVECTOR at 0x230f417bfa0>,
#   <__main__.FEAVECTOR at 0x230f41880a0>,
#   <__main__.FEAVECTOR at 0x230f4188220>,
#   <__main__.FEAVECTOR at 0x230f41882e0>,
#   <__main__.FEAVECTOR at 0x230f41883a0>,
#   <__main__.FEAVECTOR at 0x230f4188160>,
#   <__main__.FEAVECTOR at 0x230f4188520>,
#   <__main__.FEAVECTOR at 0x230f41885e0>,
#   <__main__.FEAVECTOR at 0x230f41886a0>,
#   <__main__.FEAVECTOR at 0x230f4188760>,
#   <__main__.FEAVECTOR at 0x230f4188820>,
#   <__main__.FEAVECTOR at 0x230f41888e0>,
#   <__main__.FEAVECTOR at 0x230f4188460>,
#   <__main__.FEAVECTOR at 0x230f4188a60>,
#   <__main__.FEAVECTOR at 0x230f4188b20>,
#   <__main__.FEAVECTOR at 0x230f4188be0>,
#   <__main__.FEAVECTOR at 0x230f4188ca0>,
#   <__main__.FEAVECTOR at 0x230f41889a0>,
#   <__main__.FEAVECTOR at 0x230f4188e20>,
#   <__main__.FEAVECTOR at 0x230f4188d60>,
#   <__main__.FEAVECTOR at 0x230f4188fa0>]]
